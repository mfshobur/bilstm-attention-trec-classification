# %%
# import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
from alstm import ALSTMModel
from nltk.corpus import stopwords
from text_preprocessor import TextPreprocessor
from training import train_model, evaluate_model, cross_validate
from preprocess import collate_fn, read_dataset, log_model_train_scenario, plot_model_history, log_report_and_conf_mat,log_model_history, TextClassificationDataset
import os
import time
import numpy as np
from torch.utils.data import ConcatDataset

# %%
def create_new_data(use_stopwords, use_stemming, use_lemma, cross_validation=False):
    """
    Return train, validation, test loader, and text preprocessor
    """
    train_df = read_dataset('../dataset/trec_train.csv')
    train_df = train_df.dropna()
    test_df = read_dataset('../dataset/trec_test.csv')
    test_df = test_df.dropna()

    # drop all abbreviation
    drop_abbreviation=True
    if drop_abbreviation:
        train_df = train_df[train_df['coarse_label'] != 0]
        train_df['coarse_label'] = train_df['coarse_label'].apply(lambda x: x-1)
        test_df = test_df[test_df['coarse_label'] != 0]
        test_df['coarse_label'] = test_df['coarse_label'].apply(lambda x: x-1)
        label_names = ["ENTY", "DESC", "HUM", "LOC", "NUM"]
    else:
        label_names = ["ABBR", "ENTY", "DESC", "HUM", "LOC", "NUM"]

    train_texts = train_df['text'].values
    test_texts = test_df['text'].values

    train_labels = train_df['coarse_label'].values
    test_labels = test_df['coarse_label'].values

    X_test = test_texts
    y_test = test_labels

    # Further split training data into train and validation
    X_train, X_val, y_train, y_val = train_test_split(
        train_texts, train_labels, test_size=0.2, random_state=42, stratify=train_labels
    )

    # Preprocess text data
    # CONFIG
    stop = set(stopwords.words('english'))
    preprocessor = TextPreprocessor(stopwords=stop, max_vocab_size=10000, max_seq_length=50)
    trec_vocab = preprocessor.get_vocab_from_texts(
        [*X_test, *X_val, *X_train],
        use_stopwords=use_stopwords,
        use_lemmatization=use_lemma,
        use_stemming=use_stemming,
    )

    preprocessor.download_model(filter_from_vocab=trec_vocab, save_embedding=True)
    # preprocessor.fit([*X_train, *X_val, *X_test])
    print(f'Jumlah vocabulary/kosa kata: {preprocessor.vocab_size}')

    # Transform texts to sequences
    X_train_seq = preprocessor.transform(X_train, use_stopwords=use_stopwords, use_stemming=use_stemming, use_lemmatization=use_lemma)
    X_val_seq = preprocessor.transform(X_val, use_stopwords=use_stopwords, use_stemming=use_stemming, use_lemmatization=use_lemma)
    X_test_seq = preprocessor.transform(X_test, use_stopwords=use_stopwords, use_stemming=use_stemming, use_lemmatization=use_lemma)

    labels = len(label_names)
    labels_total = train_df['coarse_label'].value_counts().sort_index().values
    # imbalance dataset
    # targets = []
    # targets += [[index] * labels_total[index] for index in range(labels)]
    # for i in range(labels):
    #     targets += [i] * labels_total[i]

    # Create datasets
    train_dataset = TextClassificationDataset(X_train_seq, y_train)
    val_dataset = TextClassificationDataset(X_val_seq, y_val)
    test_dataset = TextClassificationDataset(X_test_seq, y_test)

    if cross_validation:
        labels = len(label_names)
        labels_total = train_df['coarse_label'].value_counts().sort_index().values
        # imbalance dataset
        targets = [*y_train, *y_val]
        # targets += [[index] * labels_total[index] for index in range(labels)]
        # for i in range(labels):
        #     targets += [i] * labels_total[i]
        train_dataset = ConcatDataset([train_dataset, val_dataset])
        return train_dataset, None, test_dataset, preprocessor, targets

    batch_size=50
    num_workers=0

    torch.manual_seed(42)

    # Create data loaders
    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        drop_last=True,
        num_workers=num_workers,
        collate_fn=collate_fn)
    val_loader = DataLoader(
        val_dataset,
        batch_size=batch_size,
        num_workers=num_workers,
        collate_fn=collate_fn)
    test_loader = DataLoader(
        test_dataset,
        batch_size=batch_size,
        num_workers=num_workers,
        collate_fn=collate_fn)
    
    return train_loader, val_loader, test_loader, preprocessor, None

# %%
# Scenario
scenario = {
    'epoch': [20, 40, 60, 80, 100],
    'drop_rate': [0.0, 0.2, 0.4, 0.6,  0.8],
    'learning_rate': [0.1, 0.01, 0.001, 0.0001,  0.00001],
    'weight_decay': [0.1, 0.01, 0.001,  0.0001],
    'vocabulary': [None, 'use_stopwords', 'use_stemming', 'use_lemma'],
    'n_heads': [1, 2, 3, 5, 6, 10, 15, 25, 30, 50, 75, 150],
}

active_scenario = {
    'epoch': 100,
    'drop_rate': 0.6,
    'learning_rate': 0.001,
    'weight_decay': 0.01,
    'use_stopwords': False,
    'use_stemming': False,
    'use_lemma': False,
    'n_heads': 1
}

# Set device
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

label_names = ["ENTY", "DESC", "HUM", "LOC", "NUM"]
# Out:
# Using device: cuda:0

# %%
def update_current_scenario_vocab(active_scenario: dict, current_value):
    if current_value is None:
        for key in active_scenario.keys():
            if 'use' in key:
                active_scenario[key] = False
    else:
        for key in active_scenario.keys():
            if 'use' in key:
                if key == current_value:
                    active_scenario[key] = True
                else:
                    active_scenario[key] = False
    return active_scenario

# %%
active_scenario
# Out:
# {'epoch': 100,
#  'drop_rate': 0.6,
#  'learning_rate': 0.001,
#  'weight_decay': 0.01,
#  'use_stopwords': False,
#  'use_stemming': False,
#  'use_lemma': False,
#  'n_heads': 1}

# %%
use_cross_validation=True
k_fold=10

g = torch.Generator()
g.manual_seed(42)

train_loader, val_loader, test_loader, preprocessor, targets = create_new_data(
    use_stopwords=active_scenario['use_stopwords'],
    use_lemma=active_scenario['use_lemma'],
    use_stemming=active_scenario['use_stemming'],
    cross_validation=use_cross_validation
)
label_names = ["ENTY", "DESC", "HUM", "LOC", "NUM"]

no = 0
folder = 'scenario'
csv_path = f'{folder}/scenario.csv'

skip_until = 20

if not os.path.exists(folder):
    os.mkdir(folder)

# run through all scenarios (keys)
for i, key in enumerate(scenario.keys()):
    scenario_num = i+1
    print(f'Scenario {scenario_num}: {key}')
    val_loss = []
    val_accs = []
    
    folder_path = f'{folder}/{scenario_num}'
    # create folder if not exist
    if not os.path.exists(folder_path):
        os.mkdir(folder_path)

    # run all value inside the scenario
    for value in scenario[key]:
        model_name = f'model_{key}_{value}'
        model_folder = f'{folder_path}/{model_name}'
        # create folder if not exist
        if not os.path.exists(model_folder):
            os.mkdir(model_folder)

        no += 1

        if no < skip_until:
            continue

        if value is not None and key == 'vocabulary':
            active_scenario = update_current_scenario_vocab(active_scenario, value)
            train_loader, val_loader, test_loader, preprocessor = create_new_data(
                use_stopwords=active_scenario['use_stopwords'],
                use_lemma=active_scenario['use_lemma'],
                use_stemming=active_scenario['use_stemming'],
                cross_validation=use_cross_validation,
            )
            print('\nNew data generated')
        if key != 'vocabulary':
            active_scenario[key] = value

        # update the value for active scenario key
        print(f'{no}. {active_scenario}')
        
        # Initialize model
        cfg = {
            'drop_rate': active_scenario['drop_rate'],
            'output': 5,
            'bidirectional': True,
            'vocab_size': preprocessor.vocab_size,
            'context_length': 100,
            'emb_dim': 300,
            'hidden_size': 150,
            'qkv_bias': False,
            'n_heads': active_scenario['n_heads'],
            'device': device,
            'lstm_layers': 1,
        }
        
        criterion = nn.CrossEntropyLoss()

        start_train = time.time()

        print(f'Starting training for scenario {scenario_num}-{key}: {value}')

        # train model
        if not use_cross_validation:
            model = ALSTMModel(cfg)
            model.to(device)

            # copy embedding google-news-300
            model.embedding.weight.data.copy_(torch.from_numpy(preprocessor.embedding_matrix))
            # freeze layer embedding
            model.embedding.weight.requires_grad = False

            optimizer = optim.AdamW(model.parameters(), lr=active_scenario['learning_rate'], weight_decay=active_scenario['weight_decay'])
            history = train_model(
                model=model,
                train_loader=train_loader,
                valid_loader=val_loader,
                criterion=criterion,
                optimizer=optimizer,
                device=device,
                num_epochs=active_scenario['epoch'],
                log=False,
                best_model_path=f'{model_folder}/{model_name}.pt'
            )
        else:
            history, test_acc, test_loss, report, conf_mat, model = cross_validate(
                cfg=cfg,
                preprocessor=preprocessor,
                train_dataset=train_loader,
                test_dataset=test_loader,
                targets=targets,
                criterion=criterion,
                learning_rate=active_scenario['learning_rate'],
                weight_decay=active_scenario['weight_decay'],
                collate_fn=collate_fn,
                label_names=label_names,
                fold=k_fold,
                batch_size=50,
                num_epochs=active_scenario['epoch'],
                best_model_path=f'{model_folder}/{model_name}.pt',
                debug=False,
                device=device,
            )

        end_train = time.time()
        total_train = (end_train - start_train)
        if use_cross_validation:
            # mean of total train
            total_train = total_train / k_fold

        # change time format to MM:SS
        minutes, seconds = divmod(int(total_train), 60)
        formatted_time = f"{minutes:02d}:{seconds:02d}"


        # evaluate data on test dataset
        if not use_cross_validation:
            model.load_state_dict(torch.load(f'{model_folder}/{model_name}.pt', weights_only=True))
            model.to(device)
            test_loss, test_acc, report, conf_mat = evaluate_model(
                model=model,
                test_loader=test_loader,
                criterion=criterion,
                device=device,
                label_names=label_names,
                return_report=True
            )
            print(f"Test accuracy: {test_acc:.4f}")

        
        # save model's validation loss
        val_loss.append(test_loss)
        val_accs.append(test_acc)

        # simpan log training dan testing
        plot_model_history(
            history=history,
            title=model_name,
            save_path=f'{model_folder}/train_test_graph.png'
        )

        log_model_history(
            history,
            save_path=f'{model_folder}/train_valid_log.csv'
        )

        log_report_and_conf_mat(
            title=model_name,
            report=report,
            confusion_matrix=conf_mat,
            label_names=label_names,
            save_path=f'{model_folder}/classification_report_and_confusion_matrix.png'
        )
        
        log_model_train_scenario(
            scenario_num=scenario_num,
            scenario=key,
            epoch=active_scenario['epoch'],
            drop_rate=active_scenario['drop_rate'],
            learning_rate=active_scenario['learning_rate'],
            weight_decay=active_scenario['weight_decay'],
            vocabulary='use_stopwords' if active_scenario['use_stopwords'] else 'use_stemming' if active_scenario['use_stemming'] else 'use_lemma' if active_scenario['use_lemma'] else None,
            n_heads=active_scenario['n_heads'],
            vocabulary_total=preprocessor.vocab_size,
            train_acc=f"{history['train_accs'][-1]:.4f}",
            test_acc=test_acc,
            train_loss=f"{history['train_losses'][-1]:.4f}",
            test_loss=test_loss,
            time=formatted_time,
            file=csv_path,
        )

        print(f'Training finished. Total time: {formatted_time}\n')

        # hapus model dan optimizer untuk meringankan memori
        if not use_cross_validation:
            del model
            del optimizer

    if len(val_accs) == 0:
        continue

    # print(f"\nBest value from {key} is {scenario[key][np.argmin(val_loss)]}\n")
    print(f"\nBest value from {key} is {scenario[key][np.argmax(val_accs)]}\n")
    # create new data if previously process vocabulary scenario
    if key == 'vocabulary':
        # min_index = np.argmin(val_loss)
        # value = scenario[key][min_index]
        max_index = np.argmax(val_accs)
        value = scenario[key][max_index]
        active_scenario = update_current_scenario_vocab(active_scenario, value)
        train_loader, val_loader, test_loader, preprocessor = create_new_data(
            use_stopwords=active_scenario['use_stopwords'],
            use_lemma=active_scenario['use_lemma'],
            use_stemming=active_scenario['use_stemming'],
            use_cross_validation=use_cross_validation,
        )
        print('\nNew data generated')
    else:
        # check for the hyperparameter with least loss and set it as active scenario
        # min_index = np.argmin(val_loss)
        # active_scenario[key] = scenario[key][min_index]
        max_index = np.argmax(val_accs)
        active_scenario[key] = scenario[key][max_index]
# Out:
# Jumlah vocabulary/kosa kata: 8898
# Scenario 1: epoch
# Scenario 2: drop_rate
# Scenario 3: learning_rate
# 11. {'epoch': 100, 'drop_rate': 0.6, 'learning_rate': 0.1, 'weight_decay': 0.01, 'use_stopwords': False, 'use_stemming': False, 'use_lemma': False, 'n_heads': 1}
# Starting training for scenario 3-learning_rate: 0.1
# Total fold: 10
# Fold: 1:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 1.210137486679816
#
# New model saved from fold 1
#
# Fold: 2:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 1.4757720349665238
#
# Fold: 3:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 1.3074992697554149
#
# Fold: 4:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.43540807387460323
#
# New model saved from fold 4
#
# Fold: 5:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 1.5975464165099729
#
# Fold: 6:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 1.596855946981263
#
# Fold: 7:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 122 (22.76%)
#   Class 3: 84 (15.67%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 1.5805749951013879
#
# Fold: 8:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 1.5965047763354743
#
# Fold: 9:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.7870773544062429
#
# Fold: 10:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 1.3001871402583904
#
# Test Loss: 1.5853, Test Acc: 0.2811
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         ENTY       0.00      0.00      0.00        94
#         DESC       0.28      1.00      0.44       138
#          HUM       0.00      0.00      0.00        65
#          LOC       0.00      0.00      0.00        81
#          NUM       0.00      0.00      0.00       113
#
#     accuracy                           0.28       491
#    macro avg       0.06      0.20      0.09       491
# weighted avg       0.08      0.28      0.12       491
#
#
# Confusion Matrix:
# [[  0  94   0   0   0]
#  [  0 138   0   0   0]
#  [  0  65   0   0   0]
#  [  0  81   0   0   0]
#  [  0 113   0   0   0]]
# Final Test Accuracy (best model): 0.2811
# model logged
# Training finished. Total time: 07:02
#
# 12. {'epoch': 100, 'drop_rate': 0.6, 'learning_rate': 0.01, 'weight_decay': 0.01, 'use_stopwords': False, 'use_stemming': False, 'use_lemma': False, 'n_heads': 1}
# Starting training for scenario 3-learning_rate: 0.01
# Total fold: 10
# Fold: 1:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 1.460634687981348
#
# New model saved from fold 1
#
# Fold: 2:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 1.5689652743064268
#
# Fold: 3:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 1.4582095104000865
#
# New model saved from fold 3
#
# Fold: 4:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 1.5935155333087432
#
# Fold: 5:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 1.596597094775578
#
# Fold: 6:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 1.5966693149598616
#
# Fold: 7:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 122 (22.76%)
#   Class 3: 84 (15.67%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 1.5668227912774726
#
# Fold: 8:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 1.4148396444854452
#
# New model saved from fold 8
#
# Fold: 9:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 1.3887801717466384
#
# New model saved from fold 9
#
# Fold: 10:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 1.5955889176076918
#
# Test Loss: 1.4400, Test Acc: 0.2872
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         ENTY       0.21      1.00      0.35        94
#         DESC       0.00      0.00      0.00       138
#          HUM       1.00      0.72      0.84        65
#          LOC       0.00      0.00      0.00        81
#          NUM       0.00      0.00      0.00       113
#
#     accuracy                           0.29       491
#    macro avg       0.24      0.34      0.24       491
# weighted avg       0.17      0.29      0.18       491
#
#
# Confusion Matrix:
# [[ 94   0   0   0   0]
#  [138   0   0   0   0]
#  [ 18   0  47   0   0]
#  [ 81   0   0   0   0]
#  [113   0   0   0   0]]
# Final Test Accuracy (best model): 0.2872
# model logged
# Training finished. Total time: 07:01
#
# 13. {'epoch': 100, 'drop_rate': 0.6, 'learning_rate': 0.001, 'weight_decay': 0.01, 'use_stopwords': False, 'use_stemming': False, 'use_lemma': False, 'n_heads': 1}
# Starting training for scenario 3-learning_rate: 0.001
# Total fold: 10
# Fold: 1:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2604914006241207
#
# New model saved from fold 1
#
# Fold: 2:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.28353909440546726
#
# Fold: 3:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.26715114782087407
#
# Fold: 4:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.21849518810404078
#
# New model saved from fold 4
#
# Fold: 5:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2604726352061195
#
# Fold: 6:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2978900877665208
#
# Fold: 7:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 122 (22.76%)
#   Class 3: 84 (15.67%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.29904522912215387
#
# Fold: 8:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.22807156423857408
#
# Fold: 9:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.30933234996315256
#
# Fold: 10:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.23452918495593675
#
# Test Loss: 0.1527, Test Acc: 0.9593
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         ENTY       0.94      0.87      0.91        94
#         DESC       0.96      0.99      0.97       138
#          HUM       0.94      0.95      0.95        65
#          LOC       0.95      0.98      0.96        81
#          NUM       0.98      0.99      0.99       113
#
#     accuracy                           0.96       491
#    macro avg       0.96      0.96      0.96       491
# weighted avg       0.96      0.96      0.96       491
#
#
# Confusion Matrix:
# [[ 82   4   3   3   2]
#  [  2 136   0   0   0]
#  [  2   0  62   1   0]
#  [  1   0   1  79   0]
#  [  0   1   0   0 112]]
# Final Test Accuracy (best model): 0.9593
# model logged
# Training finished. Total time: 07:01
#
# 14. {'epoch': 100, 'drop_rate': 0.6, 'learning_rate': 0.0001, 'weight_decay': 0.01, 'use_stopwords': False, 'use_stemming': False, 'use_lemma': False, 'n_heads': 1}
# Starting training for scenario 3-learning_rate: 0.0001
# Total fold: 10
# Fold: 1:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.28670351060187127
#
# New model saved from fold 1
#
# Fold: 2:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.40534888138540187
#
# Fold: 3:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.35257185360128873
#
# Fold: 4:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.32849626961811074
#
# Fold: 5:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.31812588432092687
#
# Fold: 6:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.3671006685056944
#
# Fold: 7:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 122 (22.76%)
#   Class 3: 84 (15.67%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.3748544921625906
#
# Fold: 8:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.32903800265335326
#
# Fold: 9:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.3659815543067099
#
# Fold: 10:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.34629437227302523
#
# Test Loss: 0.2287, Test Acc: 0.9124
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         ENTY       0.88      0.73      0.80        94
#         DESC       0.91      0.99      0.94       138
#          HUM       0.92      0.89      0.91        65
#          LOC       0.87      0.96      0.91        81
#          NUM       0.97      0.95      0.96       113
#
#     accuracy                           0.91       491
#    macro avg       0.91      0.90      0.90       491
# weighted avg       0.91      0.91      0.91       491
#
#
# Confusion Matrix:
# [[ 69  12   4   6   3]
#  [  1 136   0   1   0]
#  [  5   0  58   2   0]
#  [  2   0   1  78   0]
#  [  1   2   0   3 107]]
# Final Test Accuracy (best model): 0.9124
# model logged
# Training finished. Total time: 07:02
#
# 15. {'epoch': 100, 'drop_rate': 0.6, 'learning_rate': 1e-05, 'weight_decay': 0.01, 'use_stopwords': False, 'use_stemming': False, 'use_lemma': False, 'n_heads': 1}
# Starting training for scenario 3-learning_rate: 1e-05
# Total fold: 10
# Fold: 1:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.6223918347163351
#
# New model saved from fold 1
#
# Fold: 2:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.770187061703183
#
# Fold: 3:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.7646590644420859
#
# Fold: 4:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.6878955672795102
#
# Fold: 5:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.6842966129659941
#
# Fold: 6:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.7475299599894376
#
# Fold: 7:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 122 (22.76%)
#   Class 3: 84 (15.67%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.7103416608340705
#
# Fold: 8:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.674515473976064
#
# Fold: 9:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.7136715368103626
#
# Fold: 10:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.7014527696726928
#
# Test Loss: 0.5989, Test Acc: 0.7963
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         ENTY       0.69      0.60      0.64        94
#         DESC       0.76      0.96      0.85       138
#          HUM       0.83      0.85      0.84        65
#          LOC       0.78      0.90      0.83        81
#          NUM       0.97      0.66      0.79       113
#
#     accuracy                           0.80       491
#    macro avg       0.81      0.79      0.79       491
# weighted avg       0.81      0.80      0.79       491
#
#
# Confusion Matrix:
# [[ 56  25   5   8   0]
#  [  5 132   0   0   1]
#  [  6   2  55   2   0]
#  [  5   0   2  73   1]
#  [  9  14   4  11  75]]
# Final Test Accuracy (best model): 0.7963
# model logged
# Training finished. Total time: 07:00
#
#
# Best value from learning_rate is 0.001
#
# Scenario 4: weight_decay
# 16. {'epoch': 100, 'drop_rate': 0.6, 'learning_rate': 0.001, 'weight_decay': 0.1, 'use_stopwords': False, 'use_stemming': False, 'use_lemma': False, 'n_heads': 1}
# Starting training for scenario 4-weight_decay: 0.1
# Total fold: 10
# Fold: 1:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.26512789437668727
#
# New model saved from fold 1
#
# Fold: 2:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.28727208227751644
#
# Fold: 3:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.26533225622701023
#
# Fold: 4:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.24751414074189615
#
# New model saved from fold 4
#
# Fold: 5:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2362110187720986
#
# New model saved from fold 5
#
# Fold: 6:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.3002092497183957
#
# Fold: 7:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 122 (22.76%)
#   Class 3: 84 (15.67%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.3110747521937783
#
# Fold: 8:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.2300037603213716
#
# New model saved from fold 8
#
# Fold: 9:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.27877714473809767
#
# Fold: 10:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.24503734135138455
#
# Test Loss: 0.1767, Test Acc: 0.9511
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         ENTY       0.93      0.86      0.90        94
#         DESC       0.96      0.99      0.97       138
#          HUM       0.93      0.97      0.95        65
#          LOC       0.94      0.96      0.95        81
#          NUM       0.98      0.96      0.97       113
#
#     accuracy                           0.95       491
#    macro avg       0.95      0.95      0.95       491
# weighted avg       0.95      0.95      0.95       491
#
#
# Confusion Matrix:
# [[ 81   3   4   4   2]
#  [  2 136   0   0   0]
#  [  1   0  63   1   0]
#  [  0   2   1  78   0]
#  [  3   1   0   0 109]]
# Final Test Accuracy (best model): 0.9511
# model logged
# Training finished. Total time: 07:01
#
# 17. {'epoch': 100, 'drop_rate': 0.6, 'learning_rate': 0.001, 'weight_decay': 0.01, 'use_stopwords': False, 'use_stemming': False, 'use_lemma': False, 'n_heads': 1}
# Starting training for scenario 4-weight_decay: 0.01
# Total fold: 10
# Fold: 1:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2806004001941095
#
# New model saved from fold 1
#
# Fold: 2:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2989853992364482
#
# Fold: 3:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.247256197076936
#
# New model saved from fold 3
#
# Fold: 4:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.25410713145103536
#
# Fold: 5:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2453508077387037
#
# New model saved from fold 5
#
# Fold: 6:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2858522143735233
#
# Fold: 7:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 122 (22.76%)
#   Class 3: 84 (15.67%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.31835490242758796
#
# Fold: 8:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.25511570276219897
#
# Fold: 9:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.28762334251581734
#
# Fold: 10:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.23347937935657465
#
# New model saved from fold 10
#
# Test Loss: 0.1675, Test Acc: 0.9532
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         ENTY       0.94      0.90      0.92        94
#         DESC       0.91      0.99      0.94       138
#          HUM       0.98      0.97      0.98        65
#          LOC       0.99      0.95      0.97        81
#          NUM       0.98      0.95      0.96       113
#
#     accuracy                           0.95       491
#    macro avg       0.96      0.95      0.96       491
# weighted avg       0.95      0.95      0.95       491
#
#
# Confusion Matrix:
# [[ 85   6   1   1   1]
#  [  1 136   0   0   1]
#  [  2   0  63   0   0]
#  [  2   2   0  77   0]
#  [  0   6   0   0 107]]
# Final Test Accuracy (best model): 0.9532
# model logged
# Training finished. Total time: 07:02
#
# 18. {'epoch': 100, 'drop_rate': 0.6, 'learning_rate': 0.001, 'weight_decay': 0.001, 'use_stopwords': False, 'use_stemming': False, 'use_lemma': False, 'n_heads': 1}
# Starting training for scenario 4-weight_decay: 0.001
# Total fold: 10
# Fold: 1:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.289426225801198
#
# New model saved from fold 1
#
# Fold: 2:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2969979209828865
#
# Fold: 3:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2675201366733572
#
# New model saved from fold 3
#
# Fold: 4:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.23071477697465007
#
# New model saved from fold 4
#
# Fold: 5:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.253508652832699
#
# Fold: 6:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.3027192169810807
#
# Fold: 7:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 122 (22.76%)
#   Class 3: 84 (15.67%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.3303275298772018
#
# Fold: 8:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.21417043182943293
#
# New model saved from fold 8
#
# Fold: 9:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.292579234313609
#
# Fold: 10:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.2569649291238678
#
# Test Loss: 0.2170, Test Acc: 0.9532
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         ENTY       0.93      0.86      0.90        94
#         DESC       0.93      0.99      0.96       138
#          HUM       0.97      0.95      0.96        65
#          LOC       0.97      0.96      0.97        81
#          NUM       0.97      0.97      0.97       113
#
#     accuracy                           0.95       491
#    macro avg       0.96      0.95      0.95       491
# weighted avg       0.95      0.95      0.95       491
#
#
# Confusion Matrix:
# [[ 81   7   2   1   3]
#  [  1 137   0   0   0]
#  [  2   0  62   1   0]
#  [  2   1   0  78   0]
#  [  1   2   0   0 110]]
# Final Test Accuracy (best model): 0.9532
# model logged
# Training finished. Total time: 07:04
#
# 19. {'epoch': 100, 'drop_rate': 0.6, 'learning_rate': 0.001, 'weight_decay': 0.0001, 'use_stopwords': False, 'use_stemming': False, 'use_lemma': False, 'n_heads': 1}
# Starting training for scenario 4-weight_decay: 0.0001
# Total fold: 10
# Fold: 1:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.26902745078617857
#
# New model saved from fold 1
#
# Fold: 2:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.3222646556475531
#
# Fold: 3:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2591132551598149
#
# New model saved from fold 3
#
# Fold: 4:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.23037651625203465
#
# New model saved from fold 4
#
# Fold: 5:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2631293852957489
#
# Fold: 6:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2979557827614539
#
# Fold: 7:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 122 (22.76%)
#   Class 3: 84 (15.67%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.30049982455684177
#
# Fold: 8:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.23778191372863391
#
# Fold: 9:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.2909240122995715
#
# Fold: 10:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.23583153932730652
#
# Test Loss: 0.1633, Test Acc: 0.9532
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         ENTY       0.95      0.84      0.89        94
#         DESC       0.94      0.99      0.96       138
#          HUM       0.95      0.95      0.95        65
#          LOC       0.94      0.99      0.96        81
#          NUM       0.98      0.97      0.98       113
#
#     accuracy                           0.95       491
#    macro avg       0.95      0.95      0.95       491
# weighted avg       0.95      0.95      0.95       491
#
#
# Confusion Matrix:
# [[ 79   7   3   3   2]
#  [  1 137   0   0   0]
#  [  1   0  62   2   0]
#  [  1   0   0  80   0]
#  [  1   2   0   0 110]]
# Final Test Accuracy (best model): 0.9532
# model logged
# Training finished. Total time: 07:01
#
#
# Best value from weight_decay is 0.01
#
# Scenario 5: vocabulary
# 20. {'epoch': 100, 'drop_rate': 0.6, 'learning_rate': 0.001, 'weight_decay': 0.01, 'use_stopwords': False, 'use_stemming': False, 'use_lemma': False, 'n_heads': 1}
# Starting training for scenario 5-vocabulary: None
# Total fold: 10
# Fold: 1:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2709059220091813
#
# New model saved from fold 1
#
# Fold: 2:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2978030883844116
#
# Fold: 3:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2703219695464193
#
# New model saved from fold 3
#
# Fold: 4:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.24821997764806508
#
# New model saved from fold 4
#
# Fold: 5:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2714072447304841
#
# Fold: 6:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.3175526077285048
#
# Fold: 7:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 122 (22.76%)
#   Class 3: 84 (15.67%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.28622664978255086
#
# Fold: 8:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.23895728101592456
#
# New model saved from fold 8
#
# Fold: 9:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.275492492507198
#
# Fold: 10:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.24243622123083072
#
# Test Loss: 0.1947, Test Acc: 0.9470
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         ENTY       0.96      0.85      0.90        94
#         DESC       0.90      1.00      0.95       138
#          HUM       0.97      0.95      0.96        65
#          LOC       0.95      0.95      0.95        81
#          NUM       0.98      0.96      0.97       113
#
#     accuracy                           0.95       491
#    macro avg       0.95      0.94      0.95       491
# weighted avg       0.95      0.95      0.95       491
#
#
# Confusion Matrix:
# [[ 80   8   1   3   2]
#  [  0 138   0   0   0]
#  [  1   1  62   1   0]
#  [  1   2   1  77   0]
#  [  1   4   0   0 108]]
# Final Test Accuracy (best model): 0.9470
# model logged
# Training finished. Total time: 07:02
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 51
#      49 if value is not None and key == 'vocabulary':
#      50     active_scenario = update_current_scenario_vocab(active_scenario, value)
# ---> 51     train_loader, val_loader, test_loader, preprocessor = create_new_data(
#      52         use_stopwords=active_scenario['use_stopwords'],
#      53         use_lemma=active_scenario['use_lemma'],
#      54         use_stemming=active_scenario['use_stemming'],
#      55         use_cross_validation=use_cross_validation,
#      56     )
#      57     print('\nNew data generated')
#      58 if key != 'vocabulary':
#
# TypeError: create_new_data() got an unexpected keyword argument 'use_cross_validation'
