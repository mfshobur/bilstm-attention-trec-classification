# %%
# import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
from alstm import ALSTMModel
from nltk.corpus import stopwords
from text_preprocessor import TextPreprocessor
from training import train_model, evaluate_model, cross_validate
from preprocess import collate_fn, read_dataset, log_model_train_scenario, plot_model_history, log_report_and_conf_mat,log_model_history, TextClassificationDataset
import os
import time
import numpy as np
from torch.utils.data import ConcatDataset
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
def create_new_data(use_stopwords, use_stemming, use_lemma, cross_validation=False):
    """
    Return train, validation, test loader, and text preprocessor
    """
    train_df = read_dataset('../dataset/trec_train.csv')
    train_df = train_df.dropna()
    test_df = read_dataset('../dataset/trec_test.csv')
    test_df = test_df.dropna()

    # drop all abbreviation
    drop_abbreviation=True
    if drop_abbreviation:
        train_df = train_df[train_df['coarse_label'] != 0]
        train_df['coarse_label'] = train_df['coarse_label'].apply(lambda x: x-1)
        test_df = test_df[test_df['coarse_label'] != 0]
        test_df['coarse_label'] = test_df['coarse_label'].apply(lambda x: x-1)
        label_names = ["ENTY", "DESC", "HUM", "LOC", "NUM"]
    else:
        label_names = ["ABBR", "ENTY", "DESC", "HUM", "LOC", "NUM"]

    train_texts = train_df['text'].values
    test_texts = test_df['text'].values

    train_labels = train_df['coarse_label'].values
    test_labels = test_df['coarse_label'].values

    X_test = test_texts
    y_test = test_labels

    # Further split training data into train and validation
    X_train, X_val, y_train, y_val = train_test_split(
        train_texts, train_labels, test_size=0.2, random_state=42, stratify=train_labels
    )

    # Preprocess text data
    # CONFIG
    stop = set(stopwords.words('english'))
    preprocessor = TextPreprocessor(stopwords=stop, max_vocab_size=10000, max_seq_length=50)
    trec_vocab = preprocessor.get_vocab_from_texts(
        [*X_test, *X_val, *X_train],
        use_stopwords=use_stopwords,
        use_lemmatization=use_lemma,
        use_stemming=use_stemming,
    )

    preprocessor.download_model(filter_from_vocab=trec_vocab, save_embedding=True)
    # preprocessor.fit([*X_train, *X_val, *X_test])
    print(f'Jumlah vocabulary/kosa kata: {preprocessor.vocab_size}')

    # Transform texts to sequences
    X_train_seq = preprocessor.transform(X_train, use_stopwords=use_stopwords, use_stemming=use_stemming, use_lemmatization=use_lemma)
    X_val_seq = preprocessor.transform(X_val, use_stopwords=use_stopwords, use_stemming=use_stemming, use_lemmatization=use_lemma)
    X_test_seq = preprocessor.transform(X_test, use_stopwords=use_stopwords, use_stemming=use_stemming, use_lemmatization=use_lemma)

    labels = len(label_names)
    labels_total = train_df['coarse_label'].value_counts().sort_index().values
    # imbalance dataset
    # targets = []
    # targets += [[index] * labels_total[index] for index in range(labels)]
    # for i in range(labels):
    #     targets += [i] * labels_total[i]

    # Create datasets
    train_dataset = TextClassificationDataset(X_train_seq, y_train)
    val_dataset = TextClassificationDataset(X_val_seq, y_val)
    test_dataset = TextClassificationDataset(X_test_seq, y_test)

    if cross_validation:
        labels = len(label_names)
        labels_total = train_df['coarse_label'].value_counts().sort_index().values
        # imbalance dataset
        targets = [*y_train, *y_val]
        # targets += [[index] * labels_total[index] for index in range(labels)]
        # for i in range(labels):
        #     targets += [i] * labels_total[i]
        train_dataset = ConcatDataset([train_dataset, val_dataset])
        return train_dataset, None, test_dataset, preprocessor, targets

    batch_size=50
    num_workers=0

    torch.manual_seed(42)

    # Create data loaders
    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        drop_last=True,
        num_workers=num_workers,
        collate_fn=collate_fn)
    val_loader = DataLoader(
        val_dataset,
        batch_size=batch_size,
        num_workers=num_workers,
        collate_fn=collate_fn)
    test_loader = DataLoader(
        test_dataset,
        batch_size=batch_size,
        num_workers=num_workers,
        collate_fn=collate_fn)
    
    return train_loader, val_loader, test_loader, preprocessor, None

# %%
# Scenario
scenario = {
    'epoch': [20, 40, 60, 80, 100],
    'drop_rate': [0.0, 0.2, 0.4, 0.6,  0.8],
    'learning_rate': [0.1, 0.01, 0.001, 0.001,  0.0001, 0.00001],
    'weight_decay': [0.1, 0.01, 0.001,  0.0001],
    'vocabulary': [None, 'use_stopwords', 'use_stemming', 'use_lemma'],
    'n_heads': [1, 2, 3, 5, 6, 10, 15, 25, 30, 50, 75, 150],
}

active_scenario = {
    'epoch': 20,
    'drop_rate': 0.5,
    'learning_rate': 0.001,
    'weight_decay': 0.01,
    'use_stopwords': False,
    'use_stemming': False,
    'use_lemma': False,
    'n_heads': 1
}

# Set device
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

label_names = ["ENTY", "DESC", "HUM", "LOC", "NUM"]
# Out:
# Using device: cuda:0

# %%
def update_current_scenario_vocab(active_scenario: dict, current_value):
    if current_value is None:
        for key in active_scenario.keys():
            if 'use' in key:
                active_scenario[key] = False
    else:
        for key in active_scenario.keys():
            if 'use' in key:
                if key == current_value:
                    active_scenario[key] = True
                else:
                    active_scenario[key] = False
    return active_scenario

# %%
active_scenario
# Out:
# {'epoch': 20,
#  'drop_rate': 0.5,
#  'learning_rate': 0.001,
#  'weight_decay': 0.01,
#  'use_stopwords': False,
#  'use_stemming': False,
#  'use_lemma': False,
#  'n_heads': 1}

# %%
use_cross_validation=True
k_fold=10

g = torch.Generator()
g.manual_seed(42)

train_loader, val_loader, test_loader, preprocessor, targets = create_new_data(
    use_stopwords=active_scenario['use_stopwords'],
    use_lemma=active_scenario['use_lemma'],
    use_stemming=active_scenario['use_stemming'],
    cross_validation=use_cross_validation
)
label_names = ["ENTY", "DESC", "HUM", "LOC", "NUM"]

no = 0
folder = 'scenario'
csv_path = f'{folder}/scenario.csv'

if not os.path.exists(folder):
    os.mkdir(folder)

# run through all scenarios (keys)
for i, key in enumerate(scenario.keys()):
    scenario_num = i+1
    print(f'Scenario {scenario_num}: {key}')
    val_loss = []
    val_accs = []
    
    folder_path = f'{folder}/{scenario_num}'
    # create folder if not exist
    if not os.path.exists(folder_path):
        os.mkdir(folder_path)

    # run all value inside the scenario
    for value in scenario[key]:
        model_name = f'model_{key}_{value}'
        model_folder = f'{folder_path}/{model_name}'
        # create folder if not exist
        if not os.path.exists(model_folder):
            os.mkdir(model_folder)

        no += 1
        if value is not None and key == 'vocabulary':
            active_scenario = update_current_scenario_vocab(active_scenario, value)
            train_loader, val_loader, test_loader, preprocessor = create_new_data(
                use_stopwords=active_scenario['use_stopwords'],
                use_lemma=active_scenario['use_lemma'],
                use_stemming=active_scenario['use_stemming'],
                use_cross_validation=use_cross_validation,
            )
            print('\nNew data generated')
        if key != 'vocabulary':
            active_scenario[key] = value

        # update the value for active scenario key
        print(f'{no}. {active_scenario}')
        
        # Initialize model
        cfg = {
            'drop_rate': active_scenario['drop_rate'],
            'output': 5,
            'bidirectional': True,
            'vocab_size': preprocessor.vocab_size,
            'context_length': 100,
            'emb_dim': 300,
            'hidden_size': 150,
            'qkv_bias': False,
            'n_heads': active_scenario['n_heads'],
            'device': device,
            'lstm_layers': 1,
        }
        
        criterion = nn.CrossEntropyLoss()

        start_train = time.time()

        print(f'Starting training for scenario {scenario_num}-{key}: {value}')

        # train model
        if not use_cross_validation:
            model = ALSTMModel(cfg)
            model.to(device)

            # copy embedding google-news-300
            model.embedding.weight.data.copy_(torch.from_numpy(preprocessor.embedding_matrix))
            # freeze layer embedding
            model.embedding.weight.requires_grad = False

            optimizer = optim.AdamW(model.parameters(), lr=active_scenario['learning_rate'], weight_decay=active_scenario['weight_decay'])
            history = train_model(
                model=model,
                train_loader=train_loader,
                valid_loader=val_loader,
                criterion=criterion,
                optimizer=optimizer,
                device=device,
                num_epochs=active_scenario['epoch'],
                log=False,
                best_model_path=f'{model_folder}/{model_name}.pt'
            )
        else:
            history, test_acc, test_loss, report, conf_mat, model = cross_validate(
                cfg=cfg,
                preprocessor=preprocessor,
                train_dataset=train_loader,
                test_dataset=test_loader,
                targets=targets,
                criterion=criterion,
                learning_rate=active_scenario['learning_rate'],
                weight_decay=active_scenario['weight_decay'],
                collate_fn=collate_fn,
                label_names=label_names,
                fold=k_fold,
                batch_size=50,
                num_epochs=active_scenario['epoch'],
                best_model_path=f'{model_folder}/{model_name}.pt',
                debug=False,
                device=device,
            )

        end_train = time.time()
        total_train = (end_train - start_train)
        if use_cross_validation:
            # mean of total train
            total_train = total_train / k_fold

        # change time format to MM:SS
        minutes, seconds = divmod(int(total_train), 60)
        formatted_time = f"{minutes:02d}:{seconds:02d}"


        # evaluate data on test dataset
        if not use_cross_validation:
            model.load_state_dict(torch.load(f'{model_folder}/{model_name}.pt', weights_only=True))
            model.to(device)
            test_loss, test_acc, report, conf_mat = evaluate_model(
                model=model,
                test_loader=test_loader,
                criterion=criterion,
                device=device,
                label_names=label_names,
                return_report=True
            )
            print(f"Test accuracy: {test_acc:.4f}")

        
        # save model's validation loss
        val_loss.append(test_loss)
        val_accs.append(test_acc)

        # simpan log training dan testing
        plot_model_history(
            history=history,
            title=model_name,
            save_path=f'{model_folder}/train_test_graph.png'
        )

        log_model_history(
            history,
            save_path=f'{model_folder}/train_valid_log.csv'
        )

        log_report_and_conf_mat(
            title=model_name,
            report=report,
            confusion_matrix=conf_mat,
            label_names=label_names,
            save_path=f'{model_folder}/classification_report_and_confusion_matrix.png'
        )
        
        log_model_train_scenario(
            scenario_num=scenario_num,
            scenario=key,
            epoch=active_scenario['epoch'],
            drop_rate=active_scenario['drop_rate'],
            learning_rate=active_scenario['learning_rate'],
            weight_decay=active_scenario['weight_decay'],
            vocabulary='use_stopwords' if active_scenario['use_stopwords'] else 'use_stemming' if active_scenario['use_stemming'] else 'use_lemma' if active_scenario['use_lemma'] else None,
            n_heads=active_scenario['n_heads'],
            vocabulary_total=preprocessor.vocab_size,
            train_acc=f"{history['train_accs'][-1]:.4f}",
            test_acc=test_acc,
            train_loss=f"{history['train_losses'][-1]:.4f}",
            test_loss=test_loss,
            time=formatted_time,
            file=csv_path,
        )

        print(f'Training finished. Total time: {formatted_time}\n')

        # hapus model dan optimizer untuk meringankan memori
        if not use_cross_validation:
            del model
            del optimizer

    # print(f"\nBest value from {key} is {scenario[key][np.argmin(val_loss)]}\n")
    print(f"\nBest value from {key} is {scenario[key][np.argmax(val_accs)]}\n")
    # create new data if previously process vocabulary scenario
    if key == 'vocabulary':
        # min_index = np.argmin(val_loss)
        # value = scenario[key][min_index]
        max_index = np.argmax(val_accs)
        value = scenario[key][max_index]
        active_scenario = update_current_scenario_vocab(active_scenario, value)
        train_loader, val_loader, test_loader, preprocessor = create_new_data(
            use_stopwords=active_scenario['use_stopwords'],
            use_lemma=active_scenario['use_lemma'],
            use_stemming=active_scenario['use_stemming'],
            use_cross_validation=use_cross_validation,
        )
        print('\nNew data generated')
    else:
        # check for the hyperparameter with least loss and set it as active scenario
        # min_index = np.argmin(val_loss)
        # active_scenario[key] = scenario[key][min_index]
        max_index = np.argmax(val_accs)
        value = scenario[key][max_index]
# Out:
# Jumlah vocabulary/kosa kata: 8898
# Scenario 1: epoch
# 1. {'epoch': 20, 'drop_rate': 0.5, 'learning_rate': 0.001, 'weight_decay': 0.01, 'use_stopwords': False, 'use_stemming': False, 'use_lemma': False, 'n_heads': 1}
# Starting training for scenario 1-epoch: 20
# Total fold: 10
# Fold: 1:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2914289769957629
#
# New model saved from fold 1
#
# Fold: 2:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.33689557826163824
#
# Fold: 3:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.3164293936399996
#
# Fold: 4:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.29289583621799836
#
# Fold: 5:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.3205720937951317
#
# Fold: 6:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.34489330290027614
#
# Fold: 7:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 122 (22.76%)
#   Class 3: 84 (15.67%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.3491995005187259
#
# Fold: 8:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.2943474983991082
#
# Fold: 9:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.30027391238888695
#
# Fold: 10:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.30192807439103053
#
# Test Loss: 0.1581, Test Acc: 0.9409
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         ENTY       0.87      0.89      0.88        94
#         DESC       0.97      0.93      0.95       138
#          HUM       0.93      0.95      0.94        65
#          LOC       0.97      0.96      0.97        81
#          NUM       0.96      0.96      0.96       113
#
#     accuracy                           0.94       491
#    macro avg       0.94      0.94      0.94       491
# weighted avg       0.94      0.94      0.94       491
#
#
# Confusion Matrix:
# [[ 84   2   5   1   2]
#  [  6 129   0   0   3]
#  [  3   0  62   0   0]
#  [  2   1   0  78   0]
#  [  2   1   0   1 109]]
# Final Test Accuracy (best model): 0.9409
# model logged
# Training finished. Total time: 03:45
#
# 2. {'epoch': 40, 'drop_rate': 0.5, 'learning_rate': 0.001, 'weight_decay': 0.01, 'use_stopwords': False, 'use_stemming': False, 'use_lemma': False, 'n_heads': 1}
# Starting training for scenario 1-epoch: 40
# Total fold: 10
# Fold: 1:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.27787586522168956
#
# New model saved from fold 1
#
# Fold: 2:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.28799009306470774
#
# Fold: 3:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.27555822882128383
#
# New model saved from fold 3
#
# Fold: 4:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.27083260963846073
#
# New model saved from fold 4
#
# Fold: 5:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.28509261954430093
#
# Fold: 6:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2832704255291481
#
# Fold: 7:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 122 (22.76%)
#   Class 3: 84 (15.67%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.339480985901249
#
# Fold: 8:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.24630264354063502
#
# New model saved from fold 8
#
# Fold: 9:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.2646854699714415
#
# Fold: 10:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.2577423419970185
#
# Test Loss: 0.2290, Test Acc: 0.9430
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         ENTY       0.92      0.88      0.90        94
#         DESC       0.92      0.99      0.95       138
#          HUM       1.00      0.91      0.95        65
#          LOC       0.92      0.96      0.94        81
#          NUM       0.98      0.94      0.96       113
#
#     accuracy                           0.94       491
#    macro avg       0.95      0.94      0.94       491
# weighted avg       0.94      0.94      0.94       491
#
#
# Confusion Matrix:
# [[ 83   5   0   4   2]
#  [  1 137   0   0   0]
#  [  4   0  59   2   0]
#  [  1   2   0  78   0]
#  [  1   5   0   1 106]]
# Final Test Accuracy (best model): 0.9430
# model logged
# Training finished. Total time: 07:10
#
# 3. {'epoch': 60, 'drop_rate': 0.5, 'learning_rate': 0.001, 'weight_decay': 0.01, 'use_stopwords': False, 'use_stemming': False, 'use_lemma': False, 'n_heads': 1}
# Starting training for scenario 1-epoch: 60
# Total fold: 10
# Fold: 1:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2821191912256806
#
# New model saved from fold 1
#
# Fold: 2:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2979131977540377
#
# Fold: 3:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.27206280677678196
#
# New model saved from fold 3
#
# Fold: 4:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2593064243650303
#
# New model saved from fold 4
#
# Fold: 5:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2606993788225469
#
# Fold: 6:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.29808914542087184
#
# Fold: 7:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 122 (22.76%)
#   Class 3: 84 (15.67%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.3060768382873998
#
# Fold: 8:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.2498324353581489
#
# New model saved from fold 8
#
# Fold: 9:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.2813272006364901
#
# Fold: 10:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.2658032114381221
#
# Test Loss: 0.2341, Test Acc: 0.9409
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         ENTY       0.96      0.79      0.87        94
#         DESC       0.90      1.00      0.95       138
#          HUM       0.94      0.97      0.95        65
#          LOC       0.95      0.95      0.95        81
#          NUM       0.98      0.97      0.98       113
#
#     accuracy                           0.94       491
#    macro avg       0.95      0.94      0.94       491
# weighted avg       0.94      0.94      0.94       491
#
#
# Confusion Matrix:
# [[ 74  11   4   3   2]
#  [  0 138   0   0   0]
#  [  1   0  63   1   0]
#  [  2   2   0  77   0]
#  [  0   3   0   0 110]]
# Final Test Accuracy (best model): 0.9409
# model logged
# Training finished. Total time: 10:23
#
# 4. {'epoch': 80, 'drop_rate': 0.5, 'learning_rate': 0.001, 'weight_decay': 0.01, 'use_stopwords': False, 'use_stemming': False, 'use_lemma': False, 'n_heads': 1}
# Starting training for scenario 1-epoch: 80
# Total fold: 10
# Fold: 1:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2759923088594966
#
# New model saved from fold 1
#
# Fold: 2:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.29992824340554813
#
# Fold: 3:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.30731273452218905
#
# Fold: 4:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2513995898377629
#
# New model saved from fold 4
#
# Fold: 5:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2802030145289512
#
# Fold: 6:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.31516674117946536
#
# Fold: 7:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 122 (22.76%)
#   Class 3: 84 (15.67%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.34942945990878255
#
# Fold: 8:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.25495935990405616
#
# Fold: 9:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.2851202715355069
#
# Fold: 10:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.28321835462615563
#
# Test Loss: 0.1733, Test Acc: 0.9572
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         ENTY       0.95      0.84      0.89        94
#         DESC       0.96      0.99      0.98       138
#          HUM       0.95      0.97      0.96        65
#          LOC       0.92      0.98      0.95        81
#          NUM       0.98      0.99      0.99       113
#
#     accuracy                           0.96       491
#    macro avg       0.95      0.95      0.95       491
# weighted avg       0.96      0.96      0.96       491
#
#
# Confusion Matrix:
# [[ 79   4   3   6   2]
#  [  1 137   0   0   0]
#  [  1   0  63   1   0]
#  [  2   0   0  79   0]
#  [  0   1   0   0 112]]
# Final Test Accuracy (best model): 0.9572
# model logged
# Training finished. Total time: 15:36
#
# 5. {'epoch': 100, 'drop_rate': 0.5, 'learning_rate': 0.001, 'weight_decay': 0.01, 'use_stopwords': False, 'use_stemming': False, 'use_lemma': False, 'n_heads': 1}
# Starting training for scenario 1-epoch: 100
# Total fold: 10
# Fold: 1:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.26085716766241096
#
# New model saved from fold 1
#
# Fold: 2:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.30102861679577075
#
# Fold: 3:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.27432850319579993
#
# Fold: 4:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.23484785999457597
#
# New model saved from fold 4
#
# Fold: 5:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.24840661067536424
#
# Fold: 6:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.3184051584570324
#
# Fold: 7:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 122 (22.76%)
#   Class 3: 84 (15.67%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.3361542965493985
#
# Fold: 8:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.2472611250939654
#
# Fold: 9:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
