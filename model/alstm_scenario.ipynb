# %%
# import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
from alstm import ALSTMModel
from nltk.corpus import stopwords
from text_preprocessor import TextPreprocessor
from training import train_model, evaluate_model, cross_validate
from preprocess import collate_fn, read_dataset, log_model_train_scenario, plot_model_history, log_report_and_conf_mat,log_model_history, TextClassificationDataset
import os
import time
import numpy as np
from torch.utils.data import ConcatDataset
# Out:
# [nltk_data] Error loading punkt: <urlopen error [Errno 2] No such file
# [nltk_data]     or directory>
# [nltk_data] Error loading wordnet: <urlopen error [Errno 2] No such
# [nltk_data]     file or directory>
# [nltk_data] Error loading omw-1.4: <urlopen error [Errno 2] No such
# [nltk_data]     file or directory>

# %%
def create_new_data(use_stopwords, use_stemming, use_lemma, cross_validation=False):
    """
    Return train, validation, test loader, and text preprocessor
    """
    train_df = read_dataset('../dataset/trec_train.csv')
    train_df = train_df.dropna()
    test_df = read_dataset('../dataset/trec_test.csv')
    test_df = test_df.dropna()

    # drop all abbreviation
    drop_abbreviation=True
    if drop_abbreviation:
        train_df = train_df[train_df['coarse_label'] != 0]
        train_df['coarse_label'] = train_df['coarse_label'].apply(lambda x: x-1)
        test_df = test_df[test_df['coarse_label'] != 0]
        test_df['coarse_label'] = test_df['coarse_label'].apply(lambda x: x-1)
        label_names = ["ENTY", "DESC", "HUM", "LOC", "NUM"]
    else:
        label_names = ["ABBR", "ENTY", "DESC", "HUM", "LOC", "NUM"]

    train_texts = train_df['text'].values
    test_texts = test_df['text'].values

    train_labels = train_df['coarse_label'].values
    test_labels = test_df['coarse_label'].values

    X_test = test_texts
    y_test = test_labels

    # Further split training data into train and validation
    X_train, X_val, y_train, y_val = train_test_split(
        train_texts, train_labels, test_size=0.2, random_state=42, stratify=train_labels
    )

    # Preprocess text data
    # CONFIG
    stop = set(stopwords.words('english'))
    preprocessor = TextPreprocessor(stopwords=stop, max_vocab_size=10000, max_seq_length=50)
    trec_vocab = preprocessor.get_vocab_from_texts(
        [*X_test, *X_val, *X_train],
        use_stopwords=use_stopwords,
        use_lemmatization=use_lemma,
        use_stemming=use_stemming,
    )

    preprocessor.download_model(filter_from_vocab=trec_vocab, save_embedding=True)
    # preprocessor.fit([*X_train, *X_val, *X_test])
    print(f'Jumlah vocabulary/kosa kata: {preprocessor.vocab_size}')

    # Transform texts to sequences
    X_train_seq = preprocessor.transform(X_train, use_stopwords=use_stopwords, use_stemming=use_stemming, use_lemmatization=use_lemma)
    X_val_seq = preprocessor.transform(X_val, use_stopwords=use_stopwords, use_stemming=use_stemming, use_lemmatization=use_lemma)
    X_test_seq = preprocessor.transform(X_test, use_stopwords=use_stopwords, use_stemming=use_stemming, use_lemmatization=use_lemma)

    labels = len(label_names)
    labels_total = train_df['coarse_label'].value_counts().sort_index().values
    # imbalance dataset
    # targets = []
    # targets += [[index] * labels_total[index] for index in range(labels)]
    # for i in range(labels):
    #     targets += [i] * labels_total[i]

    # Create datasets
    train_dataset = TextClassificationDataset(X_train_seq, y_train)
    val_dataset = TextClassificationDataset(X_val_seq, y_val)
    test_dataset = TextClassificationDataset(X_test_seq, y_test)

    if cross_validation:
        labels = len(label_names)
        labels_total = train_df['coarse_label'].value_counts().sort_index().values
        # imbalance dataset
        targets = [*y_train, *y_val]
        # targets += [[index] * labels_total[index] for index in range(labels)]
        # for i in range(labels):
        #     targets += [i] * labels_total[i]
        train_dataset = ConcatDataset([train_dataset, val_dataset])
        return train_dataset, None, test_dataset, preprocessor, targets

    batch_size=50
    num_workers=0

    torch.manual_seed(42)

    # Create data loaders
    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        drop_last=True,
        num_workers=num_workers,
        collate_fn=collate_fn)
    val_loader = DataLoader(
        val_dataset,
        batch_size=batch_size,
        num_workers=num_workers,
        collate_fn=collate_fn)
    test_loader = DataLoader(
        test_dataset,
        batch_size=batch_size,
        num_workers=num_workers,
        collate_fn=collate_fn)
    
    return train_loader, val_loader, test_loader, preprocessor, None

# %%
# Scenario
scenario = {
    'epoch': [20, 40, 60, 80, 100],
    'drop_rate': [0.0, 0.2, 0.4, 0.6,  0.8],
    'learning_rate': [0.1, 0.01, 0.001, 0.0001,  0.00001],
    'weight_decay': [0.1, 0.01, 0.001,  0.0001],
    'vocabulary': [None, 'use_stopwords', 'use_stemming', 'use_lemma'],
    'n_heads': [1, 2, 3, 5, 6, 10, 15, 25, 30, 50, 75, 150],
}

active_scenario = {
    'epoch': 100,
    'drop_rate': 0.8,
    'learning_rate': 0.001,
    'weight_decay': 0.01,
    'use_stopwords': False,
    'use_stemming': False,
    'use_lemma': False,
    'n_heads': 1
}

# Set device
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

label_names = ["ENTY", "DESC", "HUM", "LOC", "NUM"]
# Out:
# Using device: cuda:0

# %%
def update_current_scenario_vocab(active_scenario: dict, current_value):
    if current_value is None:
        for key in active_scenario.keys():
            if 'use' in key:
                active_scenario[key] = False
    else:
        for key in active_scenario.keys():
            if 'use' in key:
                if key == current_value:
                    active_scenario[key] = True
                else:
                    active_scenario[key] = False
    return active_scenario

# %%
active_scenario
# Out:
# {'epoch': 20,
#  'drop_rate': 0.5,
#  'learning_rate': 0.001,
#  'weight_decay': 0.01,
#  'use_stopwords': False,
#  'use_stemming': False,
#  'use_lemma': False,
#  'n_heads': 1}

# %%
use_cross_validation=True
k_fold=10

g = torch.Generator()
g.manual_seed(42)

train_loader, val_loader, test_loader, preprocessor, targets = create_new_data(
    use_stopwords=active_scenario['use_stopwords'],
    use_lemma=active_scenario['use_lemma'],
    use_stemming=active_scenario['use_stemming'],
    cross_validation=use_cross_validation
)
label_names = ["ENTY", "DESC", "HUM", "LOC", "NUM"]

no = 0
folder = 'scenario'
csv_path = f'{folder}/scenario.csv'

skip_until = 11

if not os.path.exists(folder):
    os.mkdir(folder)

# run through all scenarios (keys)
for i, key in enumerate(scenario.keys()):
    scenario_num = i+1
    print(f'Scenario {scenario_num}: {key}')
    val_loss = []
    val_accs = []
    
    folder_path = f'{folder}/{scenario_num}'
    # create folder if not exist
    if not os.path.exists(folder_path):
        os.mkdir(folder_path)

    # run all value inside the scenario
    for value in scenario[key]:
        model_name = f'model_{key}_{value}'
        model_folder = f'{folder_path}/{model_name}'
        # create folder if not exist
        if not os.path.exists(model_folder):
            os.mkdir(model_folder)

        no += 1

        if no <= skip_until:
            continue

        if value is not None and key == 'vocabulary':
            active_scenario = update_current_scenario_vocab(active_scenario, value)
            train_loader, val_loader, test_loader, preprocessor = create_new_data(
                use_stopwords=active_scenario['use_stopwords'],
                use_lemma=active_scenario['use_lemma'],
                use_stemming=active_scenario['use_stemming'],
                use_cross_validation=use_cross_validation,
            )
            print('\nNew data generated')
        if key != 'vocabulary':
            active_scenario[key] = value

        # update the value for active scenario key
        print(f'{no}. {active_scenario}')
        
        # Initialize model
        cfg = {
            'drop_rate': active_scenario['drop_rate'],
            'output': 5,
            'bidirectional': True,
            'vocab_size': preprocessor.vocab_size,
            'context_length': 100,
            'emb_dim': 300,
            'hidden_size': 150,
            'qkv_bias': False,
            'n_heads': active_scenario['n_heads'],
            'device': device,
            'lstm_layers': 1,
        }
        
        criterion = nn.CrossEntropyLoss()

        start_train = time.time()

        print(f'Starting training for scenario {scenario_num}-{key}: {value}')

        # train model
        if not use_cross_validation:
            model = ALSTMModel(cfg)
            model.to(device)

            # copy embedding google-news-300
            model.embedding.weight.data.copy_(torch.from_numpy(preprocessor.embedding_matrix))
            # freeze layer embedding
            model.embedding.weight.requires_grad = False

            optimizer = optim.AdamW(model.parameters(), lr=active_scenario['learning_rate'], weight_decay=active_scenario['weight_decay'])
            history = train_model(
                model=model,
                train_loader=train_loader,
                valid_loader=val_loader,
                criterion=criterion,
                optimizer=optimizer,
                device=device,
                num_epochs=active_scenario['epoch'],
                log=False,
                best_model_path=f'{model_folder}/{model_name}.pt'
            )
        else:
            history, test_acc, test_loss, report, conf_mat, model = cross_validate(
                cfg=cfg,
                preprocessor=preprocessor,
                train_dataset=train_loader,
                test_dataset=test_loader,
                targets=targets,
                criterion=criterion,
                learning_rate=active_scenario['learning_rate'],
                weight_decay=active_scenario['weight_decay'],
                collate_fn=collate_fn,
                label_names=label_names,
                fold=k_fold,
                batch_size=50,
                num_epochs=active_scenario['epoch'],
                best_model_path=f'{model_folder}/{model_name}.pt',
                debug=False,
                device=device,
            )

        end_train = time.time()
        total_train = (end_train - start_train)
        if use_cross_validation:
            # mean of total train
            total_train = total_train / k_fold

        # change time format to MM:SS
        minutes, seconds = divmod(int(total_train), 60)
        formatted_time = f"{minutes:02d}:{seconds:02d}"


        # evaluate data on test dataset
        if not use_cross_validation:
            model.load_state_dict(torch.load(f'{model_folder}/{model_name}.pt', weights_only=True))
            model.to(device)
            test_loss, test_acc, report, conf_mat = evaluate_model(
                model=model,
                test_loader=test_loader,
                criterion=criterion,
                device=device,
                label_names=label_names,
                return_report=True
            )
            print(f"Test accuracy: {test_acc:.4f}")

        
        # save model's validation loss
        val_loss.append(test_loss)
        val_accs.append(test_acc)

        # simpan log training dan testing
        plot_model_history(
            history=history,
            title=model_name,
            save_path=f'{model_folder}/train_test_graph.png'
        )

        log_model_history(
            history,
            save_path=f'{model_folder}/train_valid_log.csv'
        )

        log_report_and_conf_mat(
            title=model_name,
            report=report,
            confusion_matrix=conf_mat,
            label_names=label_names,
            save_path=f'{model_folder}/classification_report_and_confusion_matrix.png'
        )
        
        log_model_train_scenario(
            scenario_num=scenario_num,
            scenario=key,
            epoch=active_scenario['epoch'],
            drop_rate=active_scenario['drop_rate'],
            learning_rate=active_scenario['learning_rate'],
            weight_decay=active_scenario['weight_decay'],
            vocabulary='use_stopwords' if active_scenario['use_stopwords'] else 'use_stemming' if active_scenario['use_stemming'] else 'use_lemma' if active_scenario['use_lemma'] else None,
            n_heads=active_scenario['n_heads'],
            vocabulary_total=preprocessor.vocab_size,
            train_acc=f"{history['train_accs'][-1]:.4f}",
            test_acc=test_acc,
            train_loss=f"{history['train_losses'][-1]:.4f}",
            test_loss=test_loss,
            time=formatted_time,
            file=csv_path,
        )

        print(f'Training finished. Total time: {formatted_time}\n')

        # hapus model dan optimizer untuk meringankan memori
        if not use_cross_validation:
            del model
            del optimizer

    # print(f"\nBest value from {key} is {scenario[key][np.argmin(val_loss)]}\n")
    print(f"\nBest value from {key} is {scenario[key][np.argmax(val_accs)]}\n")
    # create new data if previously process vocabulary scenario
    if key == 'vocabulary':
        # min_index = np.argmin(val_loss)
        # value = scenario[key][min_index]
        max_index = np.argmax(val_accs)
        value = scenario[key][max_index]
        active_scenario = update_current_scenario_vocab(active_scenario, value)
        train_loader, val_loader, test_loader, preprocessor = create_new_data(
            use_stopwords=active_scenario['use_stopwords'],
            use_lemma=active_scenario['use_lemma'],
            use_stemming=active_scenario['use_stemming'],
            use_cross_validation=use_cross_validation,
        )
        print('\nNew data generated')
    else:
        # check for the hyperparameter with least loss and set it as active scenario
        # min_index = np.argmin(val_loss)
        # active_scenario[key] = scenario[key][min_index]
        max_index = np.argmax(val_accs)
        value = scenario[key][max_index]
# Out:
# Jumlah vocabulary/kosa kata: 8898
# Scenario 1: epoch
# 1. {'epoch': 20, 'drop_rate': 0.5, 'learning_rate': 0.001, 'weight_decay': 0.01, 'use_stopwords': False, 'use_stemming': False, 'use_lemma': False, 'n_heads': 1}
# Starting training for scenario 1-epoch: 20
# Total fold: 10
# Fold: 1:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.28852122472651176
#
# New model saved from fold 1
#
# Fold: 2:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.3295243354150037
#
# Fold: 3:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.305564311074589
#
# Fold: 4:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2846898955312077
#
# New model saved from fold 4
#
# Fold: 5:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.29075559912669147
#
# Fold: 6:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.33055724220929644
#
# Fold: 7:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 122 (22.76%)
#   Class 3: 84 (15.67%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.3551301715422922
#
# Fold: 8:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.2910640854110469
#
# Fold: 9:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.30522279135549246
#
# Fold: 10:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.29270841898535616
#
# Test Loss: 0.1922, Test Acc: 0.9328
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         ENTY       0.89      0.80      0.84        94
#         DESC       0.91      0.99      0.95       138
#          HUM       0.93      0.95      0.94        65
#          LOC       0.96      0.94      0.95        81
#          NUM       0.98      0.96      0.97       113
#
#     accuracy                           0.93       491
#    macro avg       0.93      0.93      0.93       491
# weighted avg       0.93      0.93      0.93       491
#
#
# Confusion Matrix:
# [[ 75  11   4   2   2]
#  [  1 137   0   0   0]
#  [  2   0  62   1   0]
#  [  4   0   1  76   0]
#  [  2   3   0   0 108]]
# Final Test Accuracy (best model): 0.9328
# dict_values(['1', '1', 'epoch', '20', '0.5', '0.001', '0.01', 'None', '8898', '1', '0.9075', '0.9327902240325866', '0.2687', '0.1922290229263228', '01:19'])
# model logged
# Training finished. Total time: 01:19
#
# 2. {'epoch': 40, 'drop_rate': 0.5, 'learning_rate': 0.001, 'weight_decay': 0.01, 'use_stopwords': False, 'use_stemming': False, 'use_lemma': False, 'n_heads': 1}
# Starting training for scenario 1-epoch: 40
# Total fold: 10
# Fold: 1:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.27432015282925726
#
# New model saved from fold 1
#
# Fold: 2:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.3104261006167925
#
# Fold: 3:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2844592872556139
#
# Fold: 4:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.28773955482594127
#
# Fold: 5:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.28561372247488137
#
# Fold: 6:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.3266827637395601
#
# Fold: 7:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 122 (22.76%)
#   Class 3: 84 (15.67%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.36179448110954976
#
# Fold: 8:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.28520679365454327
#
# Fold: 9:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.276078439414946
#
# Fold: 10:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.26932912450561775
#
# New model saved from fold 10
#
# Test Loss: 0.1673, Test Acc: 0.9409
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         ENTY       0.99      0.78      0.87        94
#         DESC       0.90      0.99      0.94       138
#          HUM       0.94      0.98      0.96        65
#          LOC       0.93      0.96      0.95        81
#          NUM       0.97      0.97      0.97       113
#
#     accuracy                           0.94       491
#    macro avg       0.95      0.94      0.94       491
# weighted avg       0.94      0.94      0.94       491
#
#
# Confusion Matrix:
# [[ 73  10   3   6   2]
#  [  0 137   0   0   1]
#  [  1   0  64   0   0]
#  [  0   2   1  78   0]
#  [  0   3   0   0 110]]
# Final Test Accuracy (best model): 0.9409
# model logged
# Training finished. Total time: 02:27
#
# 3. {'epoch': 60, 'drop_rate': 0.5, 'learning_rate': 0.001, 'weight_decay': 0.01, 'use_stopwords': False, 'use_stemming': False, 'use_lemma': False, 'n_heads': 1}
# Starting training for scenario 1-epoch: 60
# Total fold: 10
# Fold: 1:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.26495959122753676
#
# New model saved from fold 1
#
# Fold: 2:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2994577025013041
#
# Fold: 3:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2802397825753445
#
# Fold: 4:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.258615001800229
#
# New model saved from fold 4
#
# Fold: 5:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2801369315141628
#
# Fold: 6:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.3033268816519383
#
# Fold: 7:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 122 (22.76%)
#   Class 3: 84 (15.67%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.3408294042655781
#
# Fold: 8:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.25883705469209756
#
# Fold: 9:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.3008974207314982
#
# Fold: 10:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.26300394635147123
#
# Test Loss: 0.1659, Test Acc: 0.9511
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         ENTY       0.89      0.90      0.90        94
#         DESC       0.94      0.98      0.96       138
#          HUM       1.00      0.92      0.96        65
#          LOC       0.95      0.98      0.96        81
#          NUM       0.98      0.96      0.97       113
#
#     accuracy                           0.95       491
#    macro avg       0.95      0.95      0.95       491
# weighted avg       0.95      0.95      0.95       491
#
#
# Confusion Matrix:
# [[ 85   5   0   2   2]
#  [  3 135   0   0   0]
#  [  4   0  60   1   0]
#  [  2   0   0  79   0]
#  [  1   3   0   1 108]]
# Final Test Accuracy (best model): 0.9511
# model logged
# Training finished. Total time: 03:41
#
# 4. {'epoch': 80, 'drop_rate': 0.5, 'learning_rate': 0.001, 'weight_decay': 0.01, 'use_stopwords': False, 'use_stemming': False, 'use_lemma': False, 'n_heads': 1}
# Starting training for scenario 1-epoch: 80
# Total fold: 10
# Fold: 1:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2893754596261783
#
# New model saved from fold 1
#
# Fold: 2:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.30085751683463374
#
# Fold: 3:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2834834025780804
#
# New model saved from fold 3
#
# Fold: 4:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2677951200797571
#
# New model saved from fold 4
#
# Fold: 5:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.25627238865338225
#
# New model saved from fold 5
#
# Fold: 6:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.3239368461974284
#
# Fold: 7:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 122 (22.76%)
#   Class 3: 84 (15.67%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.3443614412933143
#
# Fold: 8:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.22318503963969535
#
# New model saved from fold 8
#
# Fold: 9:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.3065870443998433
#
# Fold: 10:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.27287824201717303
#
# Test Loss: 0.2436, Test Acc: 0.9511
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         ENTY       0.94      0.87      0.91        94
#         DESC       0.95      0.97      0.96       138
#          HUM       0.97      0.95      0.96        65
#          LOC       0.94      0.96      0.95        81
#          NUM       0.96      0.98      0.97       113
#
#     accuracy                           0.95       491
#    macro avg       0.95      0.95      0.95       491
# weighted avg       0.95      0.95      0.95       491
#
#
# Confusion Matrix:
# [[ 82   4   2   3   3]
#  [  3 134   0   0   1]
#  [  1   0  62   2   0]
#  [  1   1   0  78   1]
#  [  0   2   0   0 111]]
# Final Test Accuracy (best model): 0.9511
# model logged
# Training finished. Total time: 04:50
#
# 5. {'epoch': 100, 'drop_rate': 0.5, 'learning_rate': 0.001, 'weight_decay': 0.01, 'use_stopwords': False, 'use_stemming': False, 'use_lemma': False, 'n_heads': 1}
# Starting training for scenario 1-epoch: 100
# Total fold: 10
# Fold: 1:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2748104649660086
#
# New model saved from fold 1
#
# Fold: 2:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.3126737717088152
#
# Fold: 3:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.25768751202903867
#
# New model saved from fold 3
#
# Fold: 4:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2725343228893587
#
# Fold: 5:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.26083734428971395
#
# Fold: 6:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2773384946351611
#
# Fold: 7:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 122 (22.76%)
#   Class 3: 84 (15.67%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.3313474121795439
#
# Fold: 8:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.2602573738280517
#
# Fold: 9:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.3176278331275307
#
# Fold: 10:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.26580998990962756
#
# Test Loss: 0.1875, Test Acc: 0.9552
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         ENTY       0.93      0.86      0.90        94
#         DESC       0.94      0.97      0.95       138
#          HUM       0.97      0.98      0.98        65
#          LOC       0.98      0.98      0.98        81
#          NUM       0.97      0.98      0.98       113
#
#     accuracy                           0.96       491
#    macro avg       0.96      0.95      0.96       491
# weighted avg       0.95      0.96      0.95       491
#
#
# Confusion Matrix:
# [[ 81   7   2   2   2]
#  [  3 134   0   0   1]
#  [  1   0  64   0   0]
#  [  0   2   0  79   0]
#  [  2   0   0   0 111]]
# Final Test Accuracy (best model): 0.9552
# model logged
# Training finished. Total time: 06:03
#
#
# Best value from epoch is 100
#
# Scenario 2: drop_rate
# 6. {'epoch': 100, 'drop_rate': 0.0, 'learning_rate': 0.001, 'weight_decay': 0.01, 'use_stopwords': False, 'use_stemming': False, 'use_lemma': False, 'n_heads': 1}
# Starting training for scenario 2-drop_rate: 0.0
# Total fold: 10
# Fold: 1:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.34251783946372943
#
# New model saved from fold 1
#
# Fold: 2:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.42278311122729123
#
# Fold: 3:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.4081448256636465
#
# Fold: 4:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.36823179331405204
#
# Fold: 5:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.3690660119722675
#
# Fold: 6:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.42611328755233097
#
# Fold: 7:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 122 (22.76%)
#   Class 3: 84 (15.67%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.43277975939103025
#
# Fold: 8:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.3334729366782886
#
# New model saved from fold 8
#
# Fold: 9:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.4449926117685304
#
# Fold: 10:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.35239126655592845
#
# Test Loss: 0.8510, Test Acc: 0.9308
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         ENTY       0.92      0.83      0.87        94
#         DESC       0.89      0.96      0.92       138
#          HUM       0.94      0.95      0.95        65
#          LOC       0.95      0.95      0.95        81
#          NUM       0.97      0.96      0.96       113
#
#     accuracy                           0.93       491
#    macro avg       0.93      0.93      0.93       491
# weighted avg       0.93      0.93      0.93       491
#
#
# Confusion Matrix:
# [[ 78   7   3   4   2]
#  [  4 132   1   0   1]
#  [  2   1  62   0   0]
#  [  1   3   0  77   0]
#  [  0   5   0   0 108]]
# Final Test Accuracy (best model): 0.9308
# model logged
# Training finished. Total time: 06:08
#
# 7. {'epoch': 100, 'drop_rate': 0.2, 'learning_rate': 0.001, 'weight_decay': 0.01, 'use_stopwords': False, 'use_stemming': False, 'use_lemma': False, 'n_heads': 1}
# Starting training for scenario 2-drop_rate: 0.2
# Total fold: 10
# Fold: 1:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.29124057770219375
#
# New model saved from fold 1
#
# Fold: 2:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.32239632311258015
#
# Fold: 3:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.33200181646054017
#
# Fold: 4:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.32323638179115743
#
# Fold: 5:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.32858733813411917
#
# Fold: 6:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.3663638070974936
#
# Fold: 7:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 122 (22.76%)
#   Class 3: 84 (15.67%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.3927512405190005
#
# Fold: 8:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.2893256353798197
#
# New model saved from fold 8
#
# Fold: 9:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.3598536921859677
#
# Fold: 10:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.2940521570228374
#
# Test Loss: 0.3777, Test Acc: 0.9287
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         ENTY       0.86      0.81      0.84        94
#         DESC       0.96      0.97      0.96       138
#          HUM       0.93      0.98      0.96        65
#          LOC       0.89      0.95      0.92        81
#          NUM       0.98      0.93      0.95       113
#
#     accuracy                           0.93       491
#    macro avg       0.92      0.93      0.93       491
# weighted avg       0.93      0.93      0.93       491
#
#
# Confusion Matrix:
# [[ 76   5   4   7   2]
#  [  3 134   0   1   0]
#  [  1   0  64   0   0]
#  [  2   1   1  77   0]
#  [  6   0   0   2 105]]
# Final Test Accuracy (best model): 0.9287
# model logged
# Training finished. Total time: 06:00
#
# 8. {'epoch': 100, 'drop_rate': 0.4, 'learning_rate': 0.001, 'weight_decay': 0.01, 'use_stopwords': False, 'use_stemming': False, 'use_lemma': False, 'n_heads': 1}
# Starting training for scenario 2-drop_rate: 0.4
# Total fold: 10
# Fold: 1:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2680030863045314
#
# New model saved from fold 1
#
# Fold: 2:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2994791005826529
#
# Fold: 3:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.31223629170844897
#
# Fold: 4:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2746068504214065
#
# Fold: 5:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2831791814839818
#
# Fold: 6:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.31899992235046526
#
# Fold: 7:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 122 (22.76%)
#   Class 3: 84 (15.67%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.3608984338369832
#
# Fold: 8:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.27643195486891625
#
# Fold: 9:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.3365646481180369
#
# Fold: 10:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.2832554349147562
#
# Test Loss: 0.3653, Test Acc: 0.9389
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         ENTY       0.95      0.82      0.88        94
#         DESC       0.91      0.99      0.95       138
#          HUM       1.00      0.97      0.98        65
#          LOC       0.89      0.96      0.92        81
#          NUM       0.98      0.94      0.96       113
#
#     accuracy                           0.94       491
#    macro avg       0.95      0.94      0.94       491
# weighted avg       0.94      0.94      0.94       491
#
#
# Confusion Matrix:
# [[ 77   8   0   7   2]
#  [  1 137   0   0   0]
#  [  1   0  63   1   0]
#  [  1   2   0  78   0]
#  [  1   4   0   2 106]]
# Final Test Accuracy (best model): 0.9389
# model logged
# Training finished. Total time: 05:56
#
# 9. {'epoch': 100, 'drop_rate': 0.6, 'learning_rate': 0.001, 'weight_decay': 0.01, 'use_stopwords': False, 'use_stemming': False, 'use_lemma': False, 'n_heads': 1}
# Starting training for scenario 2-drop_rate: 0.6
# Total fold: 10
# Fold: 1:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.263157673970947
#
# New model saved from fold 1
#
# Fold: 2:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.30639107672417853
#
# Fold: 3:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2450263696120882
#
# New model saved from fold 3
#
# Fold: 4:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.25748186380892046
#
# Fold: 5:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.25095184349924937
#
# Fold: 6:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.28166659174962194
#
# Fold: 7:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 122 (22.76%)
#   Class 3: 84 (15.67%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.31545387681073217
#
# Fold: 8:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.2588056360107304
#
# Fold: 9:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.28783176666987476
#
# Fold: 10:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.25052612330486523
#
# Test Loss: 0.2148, Test Acc: 0.9511
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         ENTY       0.98      0.87      0.92        94
#         DESC       0.95      0.98      0.96       138
#          HUM       0.95      0.95      0.95        65
#          LOC       0.91      0.96      0.93        81
#          NUM       0.96      0.97      0.97       113
#
#     accuracy                           0.95       491
#    macro avg       0.95      0.95      0.95       491
# weighted avg       0.95      0.95      0.95       491
#
#
# Confusion Matrix:
# [[ 82   6   1   3   2]
#  [  1 135   0   0   2]
#  [  1   0  62   2   0]
#  [  0   1   2  78   0]
#  [  0   0   0   3 110]]
# Final Test Accuracy (best model): 0.9511
# model logged
# Training finished. Total time: 05:55
#
# 10. {'epoch': 100, 'drop_rate': 0.8, 'learning_rate': 0.001, 'weight_decay': 0.01, 'use_stopwords': False, 'use_stemming': False, 'use_lemma': False, 'n_heads': 1}
# Starting training for scenario 2-drop_rate: 0.8
# Total fold: 10
# Fold: 1:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2771703422735523
#
# New model saved from fold 1
#
# Fold: 2:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.313930701998581
#
# Fold: 3:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.27662822160196926
#
# New model saved from fold 3
#
# Fold: 4:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2669602787708326
#
# New model saved from fold 4
#
# Fold: 5:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2803105439165229
#
# Fold: 6:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2941279915513495
#
# Fold: 7:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 122 (22.76%)
#   Class 3: 84 (15.67%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.31585310360611374
#
# Fold: 8:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
# ...
#          LOC       0.92      0.95      0.93        81
#          NUM       0.97      0.96      0.97       113
#
#     accuracy                           0.92       491
#    macro avg       0.93      0.92      0.92       491
# weighted avg       0.93      0.92      0.92       491
#
#
# Confusion Matrix:
# [[ 68  15   4   5   2]
#  [  1 137   0   0   0]
#  [  0   2  62   1   0]
#  [  1   2   0  77   1]
#  [  0   3   0   1 109]]
# Final Test Accuracy (best model): 0.9226
# model logged
# Training finished. Total time: 05:58
#
# 14. {'epoch': 100, 'drop_rate': 0.8, 'learning_rate': 0.001, 'weight_decay': 0.01, 'use_stopwords': False, 'use_stemming': False, 'use_lemma': False, 'n_heads': 1}
# Starting training for scenario 3-learning_rate: 0.001
# Total fold: 10
# Fold: 1:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.2780586700033209
#
# New model saved from fold 1
#
# Fold: 2:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.3340657765472401
#
# Fold: 3:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.272790543970893
#
# New model saved from fold 3
#
# Fold: 4:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.26313223656495854
#
# New model saved from fold 4
#
# Fold: 5:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.25045712299131595
#
# New model saved from fold 5
#
# Fold: 6:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.32529824429661647
#
# Fold: 7:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 122 (22.76%)
#   Class 3: 84 (15.67%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.3148264218010564
#
# Fold: 8:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.25310427745553987
#
# Fold: 9:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.28232885749816006
#
# Fold: 10:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.2541697165414469
#
# Test Loss: 0.2132, Test Acc: 0.9308
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         ENTY       0.97      0.72      0.83        94
#         DESC       0.91      0.99      0.95       138
#          HUM       0.91      0.95      0.93        65
#          LOC       0.94      0.98      0.96        81
#          NUM       0.94      0.98      0.96       113
#
#     accuracy                           0.93       491
#    macro avg       0.93      0.93      0.93       491
# weighted avg       0.93      0.93      0.93       491
#
#
# Confusion Matrix:
# [[ 68  11   6   3   6]
#  [  1 137   0   0   0]
#  [  1   1  62   1   0]
#  [  0   1   0  79   1]
#  [  0   1   0   1 111]]
# Final Test Accuracy (best model): 0.9308
# model logged
# Training finished. Total time: 05:58
#
# 15. {'epoch': 100, 'drop_rate': 0.8, 'learning_rate': 0.0001, 'weight_decay': 0.01, 'use_stopwords': False, 'use_stemming': False, 'use_lemma': False, 'n_heads': 1}
# Starting training for scenario 3-learning_rate: 0.0001
# Total fold: 10
# Fold: 1:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.4635059489995186
#
# New model saved from fold 1
#
# Fold: 2:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.5753008032866253
#
# Fold: 3:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.521458386486913
#
# Fold: 4:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.46657681065564716
#
# Fold: 5:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.49373635993767495
#
# Fold: 6:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.5516680597260012
#
# Fold: 7:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 122 (22.76%)
#   Class 3: 84 (15.67%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.5303607358416514
#
# Fold: 8:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.4855551754138363
#
# Fold: 9:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.518662591812326
#
# Fold: 10:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 0.5292833062695034
#
# Test Loss: 0.4408, Test Acc: 0.8411
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         ENTY       0.78      0.63      0.69        94
#         DESC       0.73      1.00      0.85       138
#          HUM       0.98      0.78      0.87        65
#          LOC       0.91      0.86      0.89        81
#          NUM       0.97      0.84      0.90       113
#
#     accuracy                           0.84       491
#    macro avg       0.87      0.82      0.84       491
# weighted avg       0.86      0.84      0.84       491
#
#
# Confusion Matrix:
# [[ 59  28   1   4   2]
#  [  0 138   0   0   0]
#  [ 11   2  51   1   0]
#  [  5   5   0  70   1]
#  [  1  15   0   2  95]]
# Final Test Accuracy (best model): 0.8411
# model logged
# Training finished. Total time: 05:59
#
# 16. {'epoch': 100, 'drop_rate': 0.8, 'learning_rate': 1e-05, 'weight_decay': 0.01, 'use_stopwords': False, 'use_stemming': False, 'use_lemma': False, 'n_heads': 1}
# Starting training for scenario 3-learning_rate: 1e-05
# Total fold: 10
# Fold: 1:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.9331513199282314
#
# New model saved from fold 1
#
# Fold: 2:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 1.0688066948725525
#
# Fold: 3:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 1.0370910465162337
#
# Fold: 4:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 1.0049702964681486
#
# Fold: 5:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 0.9732003155367335
#
# Fold: 6:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 116 (21.60%)
#   Class 2: 122 (22.72%)
#   Class 3: 84 (15.64%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
# this fold best valid loss: 1.1078430156690005
#
# Fold: 7:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1101 (22.80%)
#   Class 3: 751 (15.55%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 122 (22.76%)
#   Class 3: 84 (15.67%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 1.0132503473936623
#
# Fold: 8:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 1.0289981233984677
#
# Fold: 9:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 1.0719940355464594
#
# Fold: 10:
# Train class distribution (%):
#   Class 0: 1125 (23.29%)
#   Class 1: 1046 (21.66%)
#   Class 2: 1100 (22.77%)
#   Class 3: 752 (15.57%)
#   Class 4: 807 (16.71%)
# Validation class distribution (%):
#   Class 0: 125 (23.32%)
#   Class 1: 116 (21.64%)
#   Class 2: 123 (22.95%)
#   Class 3: 83 (15.49%)
#   Class 4: 89 (16.60%)
# copying embedding matrix
# this fold best valid loss: 1.0266162145938447
#
# Test Loss: 0.9646, Test Acc: 0.6721
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         ENTY       0.53      0.54      0.54        94
#         DESC       0.71      0.97      0.82       138
#          HUM       0.69      0.83      0.76        65
#          LOC       0.64      0.80      0.71        81
#          NUM       1.00      0.23      0.37       113
#
#     accuracy                           0.67       491
#    macro avg       0.71      0.68      0.64       491
# weighted avg       0.73      0.67      0.64       491
#
#
# Confusion Matrix:
# [[ 51  24   4  15   0]
#  [  4 134   0   0   0]
#  [  8   1  54   2   0]
#  [ 12   1   3  65   0]
#  [ 21  29  17  20  26]]
# Final Test Accuracy (best model): 0.6721
# model logged
# Training finished. Total time: 05:58
#
#
# Best value from learning_rate is 0.001
#
# Scenario 4: weight_decay
# 17. {'epoch': 100, 'drop_rate': 0.8, 'learning_rate': 1e-05, 'weight_decay': 0.1, 'use_stopwords': False, 'use_stemming': False, 'use_lemma': False, 'n_heads': 1}
# Starting training for scenario 4-weight_decay: 0.1
# Total fold: 10
# Fold: 1:
# Train class distribution (%):
#   Class 0: 1125 (23.30%)
#   Class 1: 1045 (21.64%)
#   Class 2: 1101 (22.80%)
#   Class 3: 752 (15.57%)
#   Class 4: 806 (16.69%)
# Validation class distribution (%):
#   Class 0: 125 (23.28%)
#   Class 1: 117 (21.79%)
#   Class 2: 122 (22.72%)
#   Class 3: 83 (15.46%)
#   Class 4: 90 (16.76%)
# copying embedding matrix
