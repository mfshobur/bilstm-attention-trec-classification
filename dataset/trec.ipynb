# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
COARSE_LABEL = ["ABBR", "ENTY", "DESC", "HUM", "LOC", "NUM"]

# %%
train_df = pd.read_csv('trec_train.csv')
test_df = pd.read_csv('trec_test.csv')

# %%
train_df.head(3)
# Out:
#                                                 text  coarse_label  fine_label
# 0  How did serfdom develop in and then leave Russ...             2          26
# 1   What films featured the character Popeye Doyle ?             1           5
# 2  How can I find a list of celebrities ' real na...             2          26

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (5452, 3)
# (500, 3)

# %%
def show_histogram(train_df, test_df):
    plt.figure(figsize=(20,10))
    plt.subplot(1, 2, 1)
    train_df['coarse_label'].hist()
    plt.title('Data Train')
    plt.xticks(range(6))
    
    plt.subplot(1, 2, 2)
    test_df['coarse_label'].hist()
    plt.title('Data Test')
    plt.xticks(range(6))
    plt.show()

# %%
show_histogram(train_df, test_df)

# %% [markdown]
# # ABBVR (index 0) dihilangkan karena jumlahnya yang timpang dibandingkan dengan kategori lain dan tidak cukup urgen untuk dilakukan klasifikasi karena setiap negara dapat memiliki singkatan yang berbeda

# %%
train_df = train_df[train_df['coarse_label'] != 0]
test_df = test_df[test_df['coarse_label'] != 0]

# %%
train_df.shape
# Out:
# (5366, 3)

# %%
show_histogram(train_df, test_df)

# %% [markdown]
# # Word Cloud

# %%
from wordcloud import WordCloud

# %%
import nltk
from nltk.corpus import stopwords
stop = set(stopwords.words('english'))

train_text = " ".join([text.lower() for text in train_df['text']])
train_text
# Out:
# "how did serfdom develop in and then leave russia ? what films featured the character popeye doyle ? how can i find a list of celebrities ' real names ? what fowl grabs the spotlight after the chinese year of the monkey ? what contemptible scoundrel stole the cork from my lunch ? what team did baseball 's st. louis browns become ? what is the oldest profession ? what are liver enzymes ? name the scar-faced bounty hunter of the old west . when was ozzy osbourne born ? why do heavier objects travel downhill faster ? who was the pride of the yankees ? who killed gandhi ? what is considered the costliest disaster the insurance industry has ever faced ? what sprawling u.s. state boasts the most airports ? what did the only repealed amendment to the u.s. constitution deal with ? how many jews were executed in concentration camps during wwii ? what is `` nine inch nails '' ? what is an annotated bibliography ? what is the date of boxing day ? what articles of clothing are tokens in monopoly ? name 11 famous martyrs . what 's the olympic motto ? what is the origin of the name ` scarlett ' ? what 's the second-most-used vowel in english ? who was the inventor of silly putty ? what is the highest waterfall in the united states ? name a golf course in myrtle beach . which two states enclose chesapeake bay ? what does a spermologer collect ? how many points make up a perfect fivepin bowling score ? which company that manufactures video-game hardware sells the `` super system '' ? how many community chest cards are there in monopoly ? what do mormons believe ? when did the neanderthal man live ? in what religion was isis the nature goddess ? where do the adventures of `` the swiss family robinson '' take place ? what relative of the racoon is sometimes known as the cat-bear ? how can i register my website in yahoo for free ? what was cash-conscious colonel edwin l. drake the first to drill ? how many people in the world speak french ? how many inches over six feet is the venus de milo ? how do they find or choose witnesses to an execution ? what 1920s cowboy star rode tony the wonder horse ? what cocktail inspired john doxat to write the book stirred-not shaken ? what isps exist in the caribbean ? how do you ask a total stranger out on a date ? what weapon is the mythological character apollo most proficient with ? what country do the galapagos islands belong to ? what is ethology ? who was the prophet of the muslim people ? where did the term `` 86ed '' come from ? who is snoopy 's arch-enemy ? what is the nature of learning ? what 's the only color johnny cash wears on stage ? what 's the term for a young fox ? what u.s. state lived under six flags ? what is the kashmir issue ? where is the loop ? what does `` extended definition '' mean and how would one write a paper on it ? what country 's capital is tirana ? what is titanium ? who do herb and tootsie live next door to ? which city has the oldest relationship as a sister city with los angeles ? what is a caldera ? why do people get calluses ? what are the names of the tourist attractions in reims ? what are cushman and wakefield known for ? what body of water does the danube river flow into ? who is the founder of scientology ? what does the six-footed musca domestica become when it enters a house ? what is the history of skateboarding ? who starred in singing in the rain and the singing nun ? how do i make fuel bricks from recycled newspaper ? what 19th-century painter died in the marquesas islands ? the corpus callosum is in what part of the body ? how do i log on to home page at headquarters u.s. european command ? what country did the nazis occupy for 1 , cd nns in nnp nnp nnp . what is nebraska 's most valuable resource ? how many species of the great white shark are there ? what is the origin of head lice ? what is the nickname for the state of mississippi ? what was the first domesticated bird ? how many villi are found in the small intestine ? what country did king wenceslas r ...

# %%
train_wc = WordCloud(
    width=800,
    height=800,
    background_color='white',
    stopwords=stop,
    max_words=30
).generate(train_text)
plt.axis('off')
plt.imshow(train_wc)
plt.show()

# %% [markdown]
# ## Plot stopwords

# %%
def show_top_stopwords(df_column: pd.Series):
    corpus = []
    questions = df_column.str.split()
    questions = questions.values.tolist()
    corpus = [word for i in questions for word in i]

    from collections import defaultdict
    dic = defaultdict(int)
    for word in corpus:
        if word in stop:
            dic[word] += 1

    top = sorted(dic.items(), key=lambda x: x[1], reverse=True)[:10]
    x,y=zip(*top)
    plt.bar(x,y)
    plt.show()

# %%
show_top_stopwords(train_df['text'])

# %% [markdown]
# ## Plot kata non stopwords

# %%
def show_top_non_stopwords(df_series: pd.Series):
    from collections import Counter

    custom_stopwords = set(['?', "'s", ',', "``", "I", "l", "|", "''", '.'])
    
    questions = df_series.str.split()
    questions = questions.values.tolist()
    words = [word.lower() for i in questions for word in i]

    corpus = []
    for word in words:
        if word not in stop and word not in custom_stopwords:
            corpus.append(word)
    
    counter = Counter(corpus)
    most = counter.most_common()
    x, y = [], []
    for word, count in most[:15]:
        x.append(word)
        y.append(count)
    
    sns.barplot(x=y, y=x)

# %%
show_top_non_stopwords(train_df['text'])

# %% [markdown]
# # Apakah di pertanyaan kategori entity ada pertanyaan mengenai human?

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
train_df.style.set_properties(**{'text-align': 'left'})

entity_questions = train_df[train_df['coarse_label'] == 1]['text']

# combine all question with new line
entity_text = "\n\n".join([question for question in entity_questions])

# write to text
with open("entity_questions.txt", "w") as f:
    f.write(entity_text)

# %% [markdown]
# # Panjang rata-rata pertanyaan

# %%
train_df['text'].str.len().hist()
# Out:
# <Axes: >

# %% [markdown]
# ## Distribusi panjang kata pada seluruh pertanyaan

# %%
train_df['text'].str.split().map(lambda x: len(x)).hist()
# Out:
# <Axes: >

# %% [markdown]
# Histogram menunjukkan kebanyakan pertanyaan memiliki panjang 9 hingga 11 kata, dengan panjang paling kecil 5 kata dan paling panjang 30 kata

# %% [markdown]
# ## Pertanyaan dengan panjang kata lebih dari 20

# %%
(train_df['text'].str.split().map(lambda x: len(x)) > 25).sum()
# Out:
# 21

# %%
train_df[(train_df['text'].str.split().map(lambda x: len(x)) > 25)]
# Out:
#                                                                                                                                                                                                       text  \
# 245                                                                         How many people on the ground were killed from the bombing of Pan Am Flight 103 over Lockerbie , Scotland , December 21 , CD .
# 286                                                         Who was the author of the book about computer hackers called `` The Cuckoo 's Egg : Tracking a Spy Through the Maze of Computer Espionage '' ?
# 694                                                                                           In what sport are these following numbers relevant : 118 , 126 , 134 , 142 , 15 , 158 , 167 , 177 , and 19 ?
# 712                           What is the name of the chronic neurological autoimmune disease which attacks the protein sheath that surrounds nerve cells causing a gradual loss of movement in the body ?
# 737                                  Who was named Admiral of the Ocean Seas and Viceroy and Governor General of all the islands he might discover , and also granted 10-?? of all profits of his voyage .
# 929                                                       Name the poet of the poem which begins : I do not know much about gods ; but I think that the river Is a strong brown god-sullen , and untamed ?
# 1120                                                                       How much does it cost , average or whatever is available , to produce and send junk mail catalogues in the US ? , DT CD NN NN ,
# 1797                                                       What French designer declared : `` The jean is the destructor ! It is a dictator ! It is destroying creativity. The jean must be stopped ! '' ?
# 2022                                                            What Irwin Allen bomb has Richard Widmark saying he 'll be `` the first officer in history to get his butt kicked by a mess of bugs ! '' ?
# 2118                                                              What enigmatic U.S. vice president was once tried and acquitted for treason in a plot to set up his own independent empire in the West ?
# 2485                                          What former royal palace has served as a granary , prison , arsenal , leper colony , mint , telegraph station and whorehouse before becoming an art museum ?
# 2526                                                                                      What Aesop 's fable has the moral : `` The race is not always to the swift. Slow and steady is bound to win '' ?
# 2661  Why do people get goosebumps when they have something emotional happen to them , like when they hear a beautiful piece of music , or see something beautiful , or get aroused by someone they love ?
# 3152                                                            What is the current population for these countries : France , Spain , Italy , Greece , Austria , Germany , Switzerland , the Netherlands ?
# 3371    What architect originated the glass house designed the Chicago Federal Center had a philosophy of `` less is more , '' and produced plans that were the forerunner of the California ranch house ?
# 3473                                                                       What is the origin of the typing practice sentence `` Now is the time for all good men to come to the aid of their country '' ?
# 3557                                                        What is the origin of the term `` buffalo wings '' that is used as a menu item in bars across the nation for chicken wings in a spicey sauce ?
# 3883                                                                      Why was Henry Ford 's first automobile calleda Model T & his second type of automobile , introduced in 1928 , called a Model A ?
# 4019                                                   What American sergeant lost both of his hands in combat during World War II and then went on to act in a single movie for which he won two Oscars ?
# 4268                                                                                 What is the high pitched sound that you hear in your ear every now and then , but then it goes away , after a while ?
# 4817                           What is the name of the rare neurological disease with symptoms such as : involuntary movements , tics , swearing , and incoherent vocalizations , grunts , shouts , etc. ?
#
#       coarse_label  fine_label
# 245              5          38
# 286              3          29
# 694              1          17
# 712              1           7
# 737              3          29
# 929              3          29
# 1120             5          41
# 1797             3          29
# 2022             1           5
# 2118             3          29
# 2485             4          35
# 2526             1           5
# 2661             2          27
# 3152             5          38
# 3371             3          29
# 3473             2          25
# 3557             2          25
# 3883             2          27
# 4019             3          29
# 4268             1          13
# 4817             1           7

# %% [markdown]
# word cloud
#
# skenario pengujian attention (apa parameter yang dituning)
#
# cleaning yg data 0?
#
# apakah di entity ada human?
#
# saya menghilangkan abbr krna sangat tipang dan tidak cukup urgen utk dialukan klasifikasi dibanding kelas klainnya. karena setiap negara bisa punya abbvr berbeda

# %% [markdown]
# # Text Preprocessing

# %% [markdown]
# Beberapa data perlu diperbaiki
#
# - How do you correctly say the word ` qigong ' ?
#
# Pada data di atas, penggunaan ` dan ' tidak diperlukan
#
# - What does `` Janelle '' mean ?
#
# Pada data di atas, penggunaan `` dan '' tidak diperlukan
#
# - What 's an auberge in France ?
#
# pada data di atas, kata 's diubah menjadi is

# %%
text = "What does `` Janelle '' mean ?"

split = text.split("`")
split
# Out:
# ['What does ', '', " Janelle '' mean ?"]

# %%
import re

def clean_text(text):
    # Remove unnecessary quotes (`` and '') but keep apostrophes in contractions
    text = re.sub(r"(?<!\w)[`“”‘’]+|[`“”‘’]+(?!\w)", "", text)

    # Remove starting and ending double quotes
    text = re.sub(r'^[\'"]+(.+?)[\'"]+$', r'\1', text)

    # Remove remaining '' inside the text
    text = re.sub(r"\s?''\s?", " ", text)

    # Remove extra spaces
    text = re.sub(r"\s+", " ", text).strip()

    return text


# Contoh penggunaan:
texts = [
    "What 's the most common non-contagious disease in the world ?",
    "What does `` Janelle '' mean ?",
    "Pada data di atas, penggunaan ` dan ' tidak diperlukan",
    "Pada data di atas, penggunaan `` dan '' tidak diperlukan",
    "How do you correctly say the word ` qigong ' ?",
    '"What product doubles your pleasure , doubles your fun '' ?"'
]

cleaned_texts = [clean_text(t) for t in texts]

# Print hasil pembersihan
for original, cleaned in zip(texts, cleaned_texts):
    print(f"Original: {original}\nCleaned: {cleaned}\n")
# Out:
# Original: What 's the most common non-contagious disease in the world ?
# Cleaned: What 's the most common non-contagious disease in the world ?
#
# Original: What does `` Janelle '' mean ?
# Cleaned: What does Janelle mean ?
#
# Original: Pada data di atas, penggunaan ` dan ' tidak diperlukan
# Cleaned: Pada data di atas, penggunaan dan ' tidak diperlukan
#
# Original: Pada data di atas, penggunaan `` dan '' tidak diperlukan
# Cleaned: Pada data di atas, penggunaan dan tidak diperlukan
#
# Original: How do you correctly say the word ` qigong ' ?
# Cleaned: How do you correctly say the word qigong ' ?
#
# Original: "What product doubles your pleasure , doubles your fun  ?"
# Cleaned: What product doubles your pleasure , doubles your fun ?

# %%
import csv
from copy import deepcopy as dc

cleaned_train_df = dc(train_df)

# Apply text cleaning function
cleaned_train_df['text'] = cleaned_train_df['text'].apply(clean_text)

# Ensure no extra spaces before saving
cleaned_train_df.to_csv('cleaned_trec_train.csv', index=False)

# %%
cleaned_test_df = dc(test_df)

# Apply text cleaning function
cleaned_test_df['text'] = cleaned_test_df['text'].apply(clean_text)

# Ensure no extra spaces before saving
cleaned_test_df.to_csv('cleaned_trec_test.csv', index=False)
